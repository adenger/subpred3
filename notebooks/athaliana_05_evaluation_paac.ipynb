# %% [markdown]
# # Feature performance comparison
#
# The purpose of this notebook is to compare the classification performance of the individual features, and their combination, for A. Thaliana

# %% [markdown]
# # Imports

# %%
from subpred.transporter_dataset import create_dataset
from subpred.eval import (
    get_independent_test_set,
    optimize_hyperparams,
    preprocess_pandas,
    models_quick_compare,
    get_confusion_matrix,
    get_classification_report,
    full_test
)
from subpred.compositions import calculate_paac

# %% [markdown]
# # Dataset

# %%
df = create_dataset(
    keywords_substrate_filter=["Amino-acid transport", "Sugar transport"],
    keywords_component_filter=["Membrane"],
    keywords_transport_filter=["Transport"],
    input_file="../data/raw/swissprot/uniprot-reviewed_yes.tab.gz",
    multi_substrate="remove",
    outliers=["O81775", "Q9SW07", "Q9FHH5", "Q8S8A0", "Q3E965", "Q3EAV6", "Q3E8L0"],
    verbose=True,
    tax_ids_filter=[3702],
    output_log="../logs/athaliana_sugar_amino.log",
    sequence_clustering=70
)
# Out:
# cd-hit: clustered 165 sequences into 117 clusters at threshold 70

# %% [markdown]
# # Feature generation

# %%
labels = df.keywords_transport
labels.value_counts()
# Out:
# Sugar transport         84
# Amino-acid transport    33
# Name: keywords_transport, dtype: int64

# %%
df_paac = calculate_paac(df.sequence)
df_paac
# Out:
#                AA        AC        AD        AE        AF        AG        AH  \
# Uniprot
# Q9SFG0   0.005929  0.001976  0.000000  0.000000  0.005929  0.005929  0.000000
# Q84WN3   0.004167  0.000000  0.000000  0.004167  0.004167  0.004167  0.000000
# O04249   0.005859  0.001953  0.000000  0.003906  0.009766  0.011719  0.001953
# Q56ZZ7   0.011009  0.001835  0.003670  0.003670  0.007339  0.018349  0.000000
# Q8H184   0.004843  0.000000  0.002421  0.000000  0.007264  0.004843  0.002421
# ...           ...       ...       ...       ...       ...       ...       ...
# Q94B65   0.009317  0.000000  0.000000  0.006211  0.003106  0.006211  0.003106
# Q0WWW9   0.005386  0.000000  0.007181  0.005386  0.003591  0.003591  0.000000
# Q2V4B9   0.006073  0.000000  0.004049  0.010121  0.004049  0.008097  0.000000
# Q94EI9   0.005900  0.000000  0.005900  0.005900  0.002950  0.008850  0.000000
# F4IHS9   0.002933  0.000000  0.000000  0.000000  0.002933  0.002933  0.000000
#
#                AI        AK        AL  ...        YM        YN        YP  \
# Uniprot                                ...
# Q9SFG0   0.003953  0.003953  0.009881  ...  0.001976  0.000000  0.000000
# Q84WN3   0.008333  0.004167  0.008333  ...  0.004167  0.000000  0.000000
# O04249   0.003906  0.001953  0.005859  ...  0.000000  0.000000  0.000000
# Q56ZZ7   0.012844  0.003670  0.020183  ...  0.000000  0.000000  0.000000
# Q8H184   0.002421  0.002421  0.004843  ...  0.000000  0.002421  0.000000
# ...           ...       ...       ...  ...       ...       ...       ...
# Q94B65   0.003106  0.018634  0.018634  ...  0.000000  0.006211  0.003106
# Q0WWW9   0.003591  0.001795  0.017953  ...  0.001795  0.000000  0.000000
# Q2V4B9   0.004049  0.004049  0.010121  ...  0.000000  0.000000  0.000000
# Q94EI9   0.011799  0.000000  0.014749  ...  0.000000  0.002950  0.002950
# F4IHS9   0.008798  0.002933  0.005865  ...  0.000000  0.000000  0.000000
#
#                YQ        YR        YS        YT        YV        YW        YY
# Uniprot
# Q9SFG0   0.000000  0.001976  0.000000  0.000000  0.003953  0.000000  0.000000
# Q84WN3   0.000000  0.004167  0.000000  0.000000  0.004167  0.000000  0.004167
# O04249   0.001953  0.000000  0.003906  0.000000  0.001953  0.000000  0.000000
# Q56ZZ7   0.000000  0.000000  0.003670  0.000000  0.001835  0.001835  0.001835
# Q8H184   0.000000  0.000000  0.002421  0.002421  0.004843  0.002421  0.000000
# ...           ...       ...       ...       ...       ...       ...       ...
# Q94B65   0.000000  0.003106  0.003106  0.003106  0.000000  0.000000  0.000000
# Q0WWW9   0.001795  0.001795  0.000000  0.000000  0.001795  0.000000  0.003591
# Q2V4B9   0.000000  0.000000  0.000000  0.004049  0.006073  0.000000  0.000000
# Q94EI9   0.002950  0.000000  0.000000  0.000000  0.005900  0.000000  0.002950
# F4IHS9   0.008798  0.000000  0.005865  0.002933  0.000000  0.000000  0.000000
#
# [117 rows x 400 columns]

# %% [markdown]
# ## Independent test set

# %%
X, y, feature_names, sample_names = preprocess_pandas(
    df_paac, labels, return_names=True
)
(
    X_train,
    X_test,
    y_train,
    y_test,
    sample_names_train,
    sample_names_test,
) = get_independent_test_set(X, y, sample_names=sample_names, test_size=0.2)

# %% [markdown]
# ## Model comparison

# %%
models_quick_compare(X_train, y_train)
# Out:
#                                                         0      1      2  \
# est
# GaussianNB()                                        0.729  0.842  0.708
# KNeighborsClassifier()                              0.936  0.864  0.725
# LinearSVC(class_weight='balanced', max_iter=100...  0.808  0.927  0.887
# LinearSVC(max_iter=1000000.0)                       0.808  0.927  0.887
# RandomForestClassifier()                            0.604  0.424  0.562
# RandomForestClassifier(class_weight='balanced')     0.737  0.737  0.406
# SGDClassifier()                                     0.878  0.927  0.887
# SVC()                                               0.424  0.424  0.406
# SVC(class_weight='balanced')                        0.737  0.604  0.782
#
#                                                         3      4   mean    std
# est
# GaussianNB()                                        0.862  0.630  0.754  0.097
# KNeighborsClassifier()                              1.000  0.804  0.866  0.108
# LinearSVC(class_weight='balanced', max_iter=100...  0.926  0.750  0.860  0.078
# LinearSVC(max_iter=1000000.0)                       0.926  0.750  0.860  0.078
# RandomForestClassifier()                            0.600  0.734  0.585  0.111
# RandomForestClassifier(class_weight='balanced')     0.734  0.419  0.607  0.177
# SGDClassifier()                                     0.926  0.673  0.858  0.106
# SVC()                                               0.419  0.419  0.419  0.007
# SVC(class_weight='balanced')                        0.839  0.734  0.739  0.087

# %% [markdown]
# ## Parameter tuning

# %%
gsearch = optimize_hyperparams(
    X_train, y_train, kernel="linear", dim_reduction=None, C=[1, 10, 100]
)
best_estimator_svc = gsearch
# Out:
# {'linearsvc__C': 10, 'linearsvc__class_weight': 'balanced', 'linearsvc__dual': False, 'linearsvc__max_iter': 100000000.0}
# 0.893

# %% [markdown]
# ## Dimensionality reduction

# %%
gsearch = optimize_hyperparams(
    X_train, y_train, kernel="linear", dim_reduction="kbest", C=[1, 10, 100]
)
best_estimator_svc_kbest = gsearch
# Out:
# {'linearsvc__C': 100, 'linearsvc__class_weight': None, 'linearsvc__dual': False, 'linearsvc__max_iter': 100000000.0, 'selectkbest__k': 241}
# 0.893

# %%
gsearch = optimize_hyperparams(
    X_train,
    y_train,
    kernel="linear",
    dim_reduction="pca",
    # C=[0.1, 0.01, 0.001],
    # gamma=[0.1, 0.01, 0.001],
)
# Out:
# {'linearsvc__C': 0.1, 'linearsvc__class_weight': 'balanced', 'linearsvc__dual': True, 'linearsvc__max_iter': 100000000.0, 'pca__n_components': 0.8}
# 0.907

# %% [markdown]
# PCA seems to perform the best, how about the RBF kernel on the lower dimensional feature set?

# %%
gsearch = optimize_hyperparams(
    X_train,
    y_train,
    kernel="rbf",
    dim_reduction="pca",
    # C=[0.1, 0.01, 0.001],
    # gamma=[0.1, 0.01, 0.001],
)
best_estimator_svc_pca = gsearch
# Out:
# {'pca__n_components': 0.81, 'svc__C': 10, 'svc__class_weight': 'balanced', 'svc__gamma': 'scale'}
# 0.936

# %% [markdown]
# ## Validation

# %% [markdown]
# ### Kbest

# %%
get_confusion_matrix(X_test, y_test, best_estimator_svc_kbest, labels=labels)
# Out:
# predicted             Amino-acid transport  Sugar transport
# observed
# Amino-acid transport                     6                1
# Sugar transport                          1               16

# %%
get_classification_report(X_test, y_test, best_estimator_svc_kbest, labels=labels)
# Out:
#                       precision  recall  f1-score  support
# Amino-acid transport      0.857   0.857     0.857        7
# Sugar transport           0.941   0.941     0.941       17
# macro avg                 0.899   0.899     0.899       24
# weighted avg              0.917   0.917     0.917       24

# %% [markdown]
# ### PCA

# %%
get_confusion_matrix(X_test, y_test, best_estimator_svc_pca, labels=labels)
# Out:
# predicted             Amino-acid transport  Sugar transport
# observed
# Amino-acid transport                     7                0
# Sugar transport                          0               17

# %%
get_classification_report(X_test, y_test, best_estimator_svc_pca, labels=labels)
# Out:
#                       precision  recall  f1-score  support
# Amino-acid transport        1.0     1.0       1.0        7
# Sugar transport             1.0     1.0       1.0       17
# macro avg                   1.0     1.0       1.0       24
# weighted avg                1.0     1.0       1.0       24

# %% [markdown]
# ## Estimating validation variance
#
# Mean and standard deviation for randomly selected training and validation sets.

# %%
df_scores, df_params = full_test(
    df_paac, labels, dim_reduction="pca", kernel="rbf", repetitions=10
)

# %%
df_scores_gr = df_scores.groupby(["label", "dataset"], as_index=False)

# %% [markdown]
# #### Mean F1

# %%
df_scores_gr.mean().pivot(index="label", columns="dataset", values="F1 score")
# Out:
# dataset                 test   train
# label
# Amino-acid transport  0.8395  0.8818
# Sugar transport       0.9394  0.9554

# %% [markdown]
# #### Standard deviation F1

# %%
df_scores_gr.std().pivot(index="label", columns="dataset", values="F1 score")
# Out:
# dataset                   test     train
# label
# Amino-acid transport  0.081425  0.052482
# Sugar transport       0.028068  0.017115

# %% [markdown]
# #### Parameters

# %%
df_params
# Out:
#                           0         1         2         3         4         5  \
# pca__n_components      0.81       0.8      0.82       0.8      0.88      0.97
# svc__C                    1        10         1         1        10         1
# svc__class_weight  balanced  balanced  balanced  balanced  balanced  balanced
# svc__gamma            scale     scale      0.01      0.01     scale      0.01
#
#                           6         7         8         9
# pca__n_components       0.9      0.85      0.88       0.8
# svc__C                    1        10         1        10
# svc__class_weight  balanced  balanced  balanced  balanced
# svc__gamma            scale     scale      0.01     scale
