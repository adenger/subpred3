# %%
import sys

import pandas as pd

from subpred.transporter_dataset import create_dataset
from subpred.eval import full_test, get_independent_test_set, preprocess_pandas, optimize_hyperparams
from subpred.compositions import calculate_aac, calculate_paac
from subpred.pssm import calculate_pssms_notebook
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

LOG_FILE = "../logs/athaliana_amino_sugar_potassium.log"

# %% [markdown]
# This notebook contains the evaluation of a thaliana with four different substrates, and the set of outliers we used in the manuscript.

# %%
sodium = ["Q2UVJ5", "O04034", "Q9FKP1", "Q9LJI2", "Q9SYG9", "Q84TI7"]
gdu = ["O81775", "Q9SW07", "Q9FHH5", "Q8S8A0", "Q3E965", "Q3EAV6", "Q3E8L0"]
df_all = create_dataset(
    keywords_substrate_filter=[
        "Amino-acid transport",
        "Electron transport",
        "Sugar transport",
        "Potassium transport",
    ],
    keywords_component_filter=["Transmembrane"],
    keywords_transport_filter=["Transport"],
    input_file="../data/raw/swissprot/uniprot-reviewed_yes.tab.gz",
    multi_substrate="integrate",
    outliers=gdu + sodium,
    verbose=True,
    tax_ids_filter=[3702],
    output_log=LOG_FILE,
    sequence_clustering=70,
)
# Out:
# cd-hit: clustered 297 sequences into 223 clusters at threshold 70

# %% [markdown]
# # Feature generation

# %%
df_aac = calculate_aac(df_all.sequence)
df_paac = calculate_paac(df_all.sequence)
df_pssm = calculate_pssms_notebook(df_all.sequence)
df_combined = pd.concat([df_aac, df_paac, df_pssm], axis=1)
labels = df_all.keywords_transport
labels.value_counts()
# Out:
# Sugar transport         84
# Electron transport      56
# Potassium transport     50
# Amino-acid transport    33
# Name: keywords_transport, dtype: int64

# %% [markdown]
# # Function

# %%
def test_case(df_features, labels: pd.Series, test_name: str, **kwargs):
    for dim_reduction in [None, "pca", "kbest"]:
        print("#" * 60)
        print("Feature reduction: ", dim_reduction)
        print("#" * 60)
        df_scores, df_params = full_test(
            df_features, labels, kernel="rbf", dim_reduction=dim_reduction, **kwargs
        )
        df_scores.label = df_scores.label.map(lambda x: x.replace(" transport", ""))

        display(df_params)
        df_scores_piv = df_scores.groupby(["label", "dataset"]).mean().unstack(1)
        df_scores_piv.loc["mean"] = df_scores_piv.mean()
        display(df_scores_piv.round(3))

        g = sns.barplot(data=df_scores, y="F1 score", x="label", hue="dataset")
        g.set_ylim((0, 1))
        g.set_xlabel("")
        # plt.savefig(f"{test_name}_{dim_reduction}_barplot.png")
        plt.show()

        g = sns.boxplot(data=df_scores, y="F1 score", x="label", hue="dataset")
        g.set_xlabel("")
        g.set_ylim((0, 1))
        # plt.savefig(f"{test_name}_{dim_reduction}_boxplot.png")
        plt.show()

# %% [markdown]
# # Eval AAC

# %%
test_case(
    df_aac,
    labels,
    test_name="AAC",
    decision_function_shape=["ovo"],
    gamma=["scale"],
    class_weight=["balanced"],
    C=[1, 10, 100],
)
# Out:
# ############################################################
# Feature reduction:  None
# ############################################################
#                                      0         1         2         3  \
# svc__C                              10         1        10       100
# svc__class_weight             balanced  balanced  balanced  balanced
# svc__decision_function_shape       ovo       ovo       ovo       ovo
# svc__gamma                       scale     scale     scale     scale
#
#                                      4         5         6         7  \
# svc__C                              10        10        10        10
# svc__class_weight             balanced  balanced  balanced  balanced
# svc__decision_function_shape       ovo       ovo       ovo       ovo
# svc__gamma                       scale     scale     scale     scale
#
#                                      8         9
# svc__C                               1         1
# svc__class_weight             balanced  balanced
# svc__decision_function_shape       ovo       ovo
# svc__gamma                       scale     scale
#            F1 score
# dataset        test  train
# label
# Amino-acid    0.697  0.794
# Electron      0.890  0.893
# Potassium     0.959  0.964
# Sugar         0.863  0.887
# mean          0.852  0.885
# ############################################################
# Feature reduction:  pca
# ############################################################
#                                      0         1         2         3  \
# pca__n_components                 0.91      0.99      0.94      0.96
# svc__C                               1         1        10        10
# svc__class_weight             balanced  balanced  balanced  balanced
# svc__decision_function_shape       ovo       ovo       ovo       ovo
# svc__gamma                       scale     scale     scale     scale
#
#                                      4         5         6         7  \
# pca__n_components                 0.96      0.99      0.99      0.85
# svc__C                              10        10         1        10
# svc__class_weight             balanced  balanced  balanced  balanced
# svc__decision_function_shape       ovo       ovo       ovo       ovo
# svc__gamma                       scale     scale     scale     scale
#
#                                      8         9
# pca__n_components                 0.96      0.93
# svc__C                              10        10
# svc__class_weight             balanced  balanced
# svc__decision_function_shape       ovo       ovo
# svc__gamma                       scale     scale
#            F1 score
# dataset        test  train
# label
# Amino-acid    0.673  0.770
# Electron      0.891  0.875
# Potassium     0.959  0.945
# Sugar         0.844  0.863
# mean          0.842  0.863
# ############################################################
# Feature reduction:  kbest
# ############################################################
#                                      0         1         2         3  \
# selectkbest__k                      18        19        18        18
# svc__C                              10         1         1        10
# svc__class_weight             balanced  balanced  balanced  balanced
# svc__decision_function_shape       ovo       ovo       ovo       ovo
# svc__gamma                       scale     scale     scale     scale
#
#                                      4         5         6         7  \
# selectkbest__k                      19        18        19        17
# svc__C                              10         1        10         1
# svc__class_weight             balanced  balanced  balanced  balanced
# svc__decision_function_shape       ovo       ovo       ovo       ovo
# svc__gamma                       scale     scale     scale     scale
#
#                                      8         9
# selectkbest__k                      13        19
# svc__C                              10        10
# svc__class_weight             balanced  balanced
# svc__decision_function_shape       ovo       ovo
# svc__gamma                       scale     scale
#            F1 score
# dataset        test  train
# label
# Amino-acid    0.675  0.815
# Electron      0.862  0.892
# Potassium     0.955  0.965
# Sugar         0.875  0.896
# mean          0.842  0.892

# %% [markdown]
# # Eval PAAC

# %%
test_case(df_paac, labels, test_name="PAAC",decision_function_shape=["ovo"], gamma=["scale"], C=[1,10,100], class_weight=["balanced"])
# Out:
# ############################################################
# Feature reduction:  None
# ############################################################
#                                      0         1         2         3  \
# svc__C                              10        10         1        10
# svc__class_weight             balanced  balanced  balanced  balanced
# svc__decision_function_shape       ovo       ovo       ovo       ovo
# svc__gamma                       scale     scale     scale     scale
#
#                                      4         5         6         7  \
# svc__C                              10        10        10        10
# svc__class_weight             balanced  balanced  balanced  balanced
# svc__decision_function_shape       ovo       ovo       ovo       ovo
# svc__gamma                       scale     scale     scale     scale
#
#                                      8         9
# svc__C                              10        10
# svc__class_weight             balanced  balanced
# svc__decision_function_shape       ovo       ovo
# svc__gamma                       scale     scale
#            F1 score
# dataset        test  train
# label
# Amino-acid    0.701  0.750
# Electron      0.892  0.867
# Potassium     0.951  0.918
# Sugar         0.883  0.885
# mean          0.857  0.855
# ############################################################
# Feature reduction:  pca
# ############################################################
#                                      0         1         2         3  \
# pca__n_components                 0.99      0.99      0.99      0.99
# svc__C                              10         1         1        10
# svc__class_weight             balanced  balanced  balanced  balanced
# svc__decision_function_shape       ovo       ovo       ovo       ovo
# svc__gamma                       scale     scale     scale     scale
#
#                                      4         5         6         7  \
# pca__n_components                 0.99       0.8      0.99      0.99
# svc__C                              10        10        10        10
# svc__class_weight             balanced  balanced  balanced  balanced
# svc__decision_function_shape       ovo       ovo       ovo       ovo
# svc__gamma                       scale     scale     scale     scale
#
#                                      8         9
# pca__n_components                 0.99      0.99
# svc__C                               1         1
# svc__class_weight             balanced  balanced
# svc__decision_function_shape       ovo       ovo
# svc__gamma                       scale     scale
#            F1 score
# dataset        test  train
# label
# Amino-acid    0.647  0.641
# Electron      0.542  0.586
# Potassium     0.852  0.784
# Sugar         0.790  0.770
# mean          0.708  0.695
# ############################################################
# Feature reduction:  kbest
# ############################################################
#                                      0         1         2         3  \
# selectkbest__k                     218       260       214       324
# svc__C                              10        10        10        10
# svc__class_weight             balanced  balanced  balanced  balanced
# svc__decision_function_shape       ovo       ovo       ovo       ovo
# svc__gamma                       scale     scale     scale     scale
#
#                                      4         5         6         7  \
# selectkbest__k                     267       232       192       348
# svc__C                              10        10        10        10
# svc__class_weight             balanced  balanced  balanced  balanced
# svc__decision_function_shape       ovo       ovo       ovo       ovo
# svc__gamma                       scale     scale     scale     scale
#
#                                      8         9
# selectkbest__k                     296       284
# svc__C                               1        10
# svc__class_weight             balanced  balanced
# svc__decision_function_shape       ovo       ovo
# svc__gamma                       scale     scale
#            F1 score
# dataset        test  train
# label
# Amino-acid    0.734  0.805
# Electron      0.884  0.886
# Potassium     0.955  0.925
# Sugar         0.884  0.904
# mean          0.864  0.880

# %% [markdown]
# # PSSM

# %%
test_case(
    df_pssm,
    labels,
    test_name="PSSM",
    decision_function_shape=["ovo"],
    gamma=["scale"],
    C=[1, 10, 100],
    class_weight=["balanced"],
    feature_transformer="pssm",
    select_k_steps=10,
    max_k_to_select=400,
)
# Out:
# ############################################################
# Feature reduction:  None
# ############################################################
#                                        0         1         2         3  \
# pssmselector__iterations               3         1         3       all
# pssmselector__uniref_threshold       all        50       all        90
# svc__C                                10        10        10        10
# svc__class_weight               balanced  balanced  balanced  balanced
# svc__decision_function_shape         ovo       ovo       ovo       ovo
# svc__gamma                         scale     scale     scale     scale
#
#                                        4         5         6         7  \
# pssmselector__iterations               3       all         3         3
# pssmselector__uniref_threshold       all        50        50        50
# svc__C                                10        10        10        10
# svc__class_weight               balanced  balanced  balanced  balanced
# svc__decision_function_shape         ovo       ovo       ovo       ovo
# svc__gamma                         scale     scale     scale     scale
#
#                                        8         9
# pssmselector__iterations               3       all
# pssmselector__uniref_threshold       all       all
# svc__C                                10        10
# svc__class_weight               balanced  balanced
# svc__decision_function_shape         ovo       ovo
# svc__gamma                         scale     scale
#            F1 score
# dataset        test  train
# label
# Amino-acid    0.935  0.950
# Electron      0.974  0.983
# Potassium     0.974  0.982
# Sugar         0.975  0.968
# mean          0.964  0.971
# ############################################################
# Feature reduction:  pca
# ############################################################
#                                        0         1         2         3  \
# pca__n_components                   0.94      0.95       0.9      0.94
# pssmselector__iterations             all       all         3         3
# pssmselector__uniref_threshold       all        50        50        50
# svc__C                                10        10         1        10
# svc__class_weight               balanced  balanced  balanced  balanced
# svc__decision_function_shape         ovo       ovo       ovo       ovo
# svc__gamma                         scale     scale     scale     scale
#
#                                        4         5         6         7  \
# pca__n_components                   0.95      0.96      0.95      0.93
# pssmselector__iterations               3         3         3         3
# pssmselector__uniref_threshold        50       all       all        50
# svc__C                                 1        10        10        10
# svc__class_weight               balanced  balanced  balanced  balanced
# svc__decision_function_shape         ovo       ovo       ovo       ovo
# svc__gamma                         scale     scale     scale     scale
#
#                                        8         9
# pca__n_components                   0.92      0.95
# pssmselector__iterations               3         3
# pssmselector__uniref_threshold        50        50
# svc__C                                 1        10
# svc__class_weight               balanced  balanced
# svc__decision_function_shape         ovo       ovo
# svc__gamma                         scale     scale
#            F1 score
# dataset        test  train
# label
# Amino-acid    0.946  0.990
# Electron      0.969  0.978
# Potassium     0.984  0.984
# Sugar         0.968  0.985
# mean          0.967  0.984
# ############################################################
# Feature reduction:  kbest
# ############################################################
#                                        0         1         2         3  \
# pssmselector__iterations             all         1         3         3
# pssmselector__uniref_threshold        50        50       all        50
# selectkbest__k                       371       371       291       281
# svc__C                                10        10        10        10
# svc__class_weight               balanced  balanced  balanced  balanced
# svc__decision_function_shape         ovo       ovo       ovo       ovo
# svc__gamma                         scale     scale     scale     scale
#
#                                        4         5         6         7  \
# pssmselector__iterations               3         3       all         3
# pssmselector__uniref_threshold        90        50        50        50
# selectkbest__k                       211       361       361       161
# svc__C                                10        10        10        10
# svc__class_weight               balanced  balanced  balanced  balanced
# svc__decision_function_shape         ovo       ovo       ovo       ovo
# svc__gamma                         scale     scale     scale     scale
#
#                                        8         9
# pssmselector__iterations               3       all
# pssmselector__uniref_threshold        50        50
# selectkbest__k                       311       211
# svc__C                                10        10
# svc__class_weight               balanced  balanced
# svc__decision_function_shape         ovo       ovo
# svc__gamma                         scale     scale
#            F1 score
# dataset        test  train
# label
# Amino-acid    0.945  0.953
# Electron      0.958  0.987
# Potassium     0.978  0.987
# Sugar         0.961  0.975
# mean          0.960  0.975

# %% [markdown]
# # Combined

# %%
test_case(
    pd.concat([df_aac, df_paac, df_pssm], axis=1),
    labels,
    test_name="Combined",
    decision_function_shape=["ovo"],
    gamma=["scale"],
    C=[1, 10, 100],
    class_weight=["balanced"],
    feature_transformer="pssm",
    select_k_steps=10,
    max_k_to_select=400
)
# Out:
# ############################################################
# Feature reduction:  None
# ############################################################
#                                        0         1         2         3  \
# pssmselector__iterations             all       all       all         3
# pssmselector__uniref_threshold        50        50       all       all
# svc__C                                10        10        10        10
# svc__class_weight               balanced  balanced  balanced  balanced
# svc__decision_function_shape         ovo       ovo       ovo       ovo
# svc__gamma                         scale     scale     scale     scale
#
#                                        4         5         6         7  \
# pssmselector__iterations               3       all       all       all
# pssmselector__uniref_threshold       all        50        50       all
# svc__C                                 1        10        10        10
# svc__class_weight               balanced  balanced  balanced  balanced
# svc__decision_function_shape         ovo       ovo       ovo       ovo
# svc__gamma                         scale     scale     scale     scale
#
#                                        8         9
# pssmselector__iterations             all         3
# pssmselector__uniref_threshold        90       all
# svc__C                                 1        10
# svc__class_weight               balanced  balanced
# svc__decision_function_shape         ovo       ovo
# svc__gamma                         scale     scale
#            F1 score
# dataset        test  train
# label
# Amino-acid    0.931  0.915
# Electron      0.967  0.972
# Potassium     0.984  0.984
# Sugar         0.964  0.951
# mean          0.961  0.956
# ############################################################
# Feature reduction:  pca
# ############################################################
#                                        0         1         2         3  \
# pca__n_components                   0.81      0.83       0.8       0.8
# pssmselector__iterations             all       all       all       all
# pssmselector__uniref_threshold       all       all       all       all
# svc__C                                 1        10        10        10
# svc__class_weight               balanced  balanced  balanced  balanced
# svc__decision_function_shape         ovo       ovo       ovo       ovo
# svc__gamma                         scale     scale     scale     scale
#
#                                        4         5         6         7  \
# pca__n_components                   0.82      0.81       0.8      0.86
# pssmselector__iterations             all       all       all       all
# pssmselector__uniref_threshold       all       all       all       all
# svc__C                                10        10        10        10
# svc__class_weight               balanced  balanced  balanced  balanced
# svc__decision_function_shape         ovo       ovo       ovo       ovo
# svc__gamma                         scale     scale     scale     scale
#
#                                        8         9
# pca__n_components                    0.8      0.81
# pssmselector__iterations             all       all
# pssmselector__uniref_threshold       all       all
# svc__C                                10        10
# svc__class_weight               balanced  balanced
# svc__decision_function_shape         ovo       ovo
# svc__gamma                         scale     scale
#            F1 score
# dataset        test  train
# label
# Amino-acid    0.913  0.911
# Electron      0.945  0.942
# Potassium     0.990  0.985
# Sugar         0.952  0.945
# mean          0.950  0.946
# ############################################################
# Feature reduction:  kbest
# ############################################################
#                                        0         1         2         3  \
# pssmselector__iterations             all         1       all         3
# pssmselector__uniref_threshold        50        50       all        50
# selectkbest__k                       391       361       251       331
# svc__C                                10        10        10        10
# svc__class_weight               balanced  balanced  balanced  balanced
# svc__decision_function_shape         ovo       ovo       ovo       ovo
# svc__gamma                         scale     scale     scale     scale
#
#                                        4         5         6         7  \
# pssmselector__iterations               3         3       all         3
# pssmselector__uniref_threshold       all       all        50        50
# selectkbest__k                       351       351       331       291
# svc__C                                10        10        10        10
# svc__class_weight               balanced  balanced  balanced  balanced
# svc__decision_function_shape         ovo       ovo       ovo       ovo
# svc__gamma                         scale     scale     scale     scale
#
#                                        8         9
# pssmselector__iterations               3       all
# pssmselector__uniref_threshold        50        90
# selectkbest__k                       231       151
# svc__C                                10        10
# svc__class_weight               balanced  balanced
# svc__decision_function_shape         ovo       ovo
# svc__gamma                         scale     scale
#            F1 score
# dataset        test  train
# label
# Amino-acid    0.922  0.942
# Electron      0.960  0.975
# Potassium     0.989  0.984
# Sugar         0.953  0.969
# mean          0.956  0.968
