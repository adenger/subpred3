# %% [markdown]
# # AAC feature evaluation

# %% [markdown]
# # Imports

# %%
from subpred.transporter_dataset import create_dataset
from subpred.eval import (
    get_independent_test_set,
    optimize_hyperparams,
    preprocess_pandas,
    models_quick_compare,
    get_confusion_matrix,
    get_classification_report,
    full_test
)
from subpred.compositions import calculate_aac

# %% [markdown]
# # Dataset

# %%
df = create_dataset(
    keywords_substrate_filter = ["Amino-acid transport","Sugar transport"],
    keywords_component_filter = ["Transmembrane"],
    keywords_transport_filter = ["Transport"],
    input_file = "../data/raw/swissprot/uniprot-reviewed_yes.tab.gz",
    multi_substrate = "integrate",
    verbose = True,
    tax_ids_filter = [9606],
    output_log = "../logs/human_amino_sugar_dataset.log",
    outliers=["Q9HBR0", "Q07837"],
    sequence_clustering=70
)
# Out:
# cd-hit: clustered 85 sequences into 81 clusters at threshold 70

# %% [markdown]
# # Feature generation
#
# ## Labels

# %%
labels = df.keywords_transport
labels.value_counts()
# Out:
# Amino-acid transport    48
# Sugar transport         33
# Name: keywords_transport, dtype: int64

# %% [markdown]
# There will be a relatively low number of samples available for training and testing, only 0.8\*0.8\*33 for sugar. This is likely not enough. We will try LOOCV later.

# %% [markdown]
# ## AAC

# %%
df_aac = calculate_aac(df.sequence)
df_aac
# Out:
#                 A         C         D         E         F         G         H  \
# Uniprot
# Q9BRV3   0.058824  0.022624  0.031674  0.018100  0.058824  0.072398  0.009050
# Q5M8T2   0.096154  0.024038  0.024038  0.050481  0.038462  0.093750  0.012019
# Q969S0   0.069486  0.018127  0.015106  0.033233  0.090634  0.060423  0.018127
# O75387   0.076923  0.026834  0.028623  0.035778  0.064401  0.078712  0.012522
# Q9NTN3   0.090141  0.011268  0.030986  0.039437  0.076056  0.076056  0.005634
# ...           ...       ...       ...       ...       ...       ...       ...
# Q96A29   0.082418  0.024725  0.024725  0.032967  0.054945  0.079670  0.008242
# Q9BYW1   0.098790  0.032258  0.012097  0.054435  0.048387  0.100806  0.010081
# P14672   0.086444  0.005894  0.011788  0.051081  0.053045  0.104126  0.007859
# Q96AA3   0.075786  0.018484  0.018484  0.040665  0.072089  0.070240  0.016636
# Q92536   0.073786  0.025243  0.029126  0.044660  0.069903  0.066019  0.011650
#
#                 I         K         L         M         N         P         Q  \
# Uniprot
# Q9BRV3   0.045249  0.022624  0.176471  0.027149  0.031674  0.040724  0.045249
# Q5M8T2   0.052885  0.026442  0.129808  0.021635  0.019231  0.048077  0.028846
# Q969S0   0.090634  0.045317  0.126888  0.036254  0.045317  0.036254  0.024169
# O75387   0.046512  0.028623  0.148479  0.035778  0.035778  0.046512  0.041145
# Q9NTN3   0.061972  0.061972  0.129577  0.030986  0.039437  0.022535  0.025352
# ...           ...       ...       ...       ...       ...       ...       ...
# Q96A29   0.038462  0.038462  0.162088  0.027473  0.035714  0.038462  0.021978
# Q9BYW1   0.064516  0.018145  0.157258  0.032258  0.018145  0.046371  0.034274
# P14672   0.066798  0.015717  0.155206  0.023576  0.025540  0.058939  0.045187
# Q96AA3   0.046211  0.031423  0.179298  0.014787  0.027726  0.029575  0.033272
# Q92536   0.083495  0.027184  0.114563  0.021359  0.031068  0.052427  0.027184
#
#                 R         S         T         V         W         Y
# Uniprot
# Q9BRV3   0.045249  0.063348  0.072398  0.072398  0.027149  0.058824
# Q5M8T2   0.048077  0.088942  0.062500  0.098558  0.009615  0.026442
# Q969S0   0.030211  0.063444  0.063444  0.075529  0.018127  0.039275
# O75387   0.039356  0.075134  0.076923  0.057245  0.016100  0.028623
# Q9NTN3   0.028169  0.059155  0.076056  0.081690  0.011268  0.042254
# ...           ...       ...       ...       ...       ...       ...
# Q96A29   0.032967  0.079670  0.074176  0.082418  0.024725  0.035714
# Q9BYW1   0.060484  0.062500  0.044355  0.066532  0.016129  0.022177
# P14672   0.045187  0.070727  0.051081  0.080550  0.013752  0.027505
# Q96AA3   0.046211  0.068392  0.066543  0.090573  0.022181  0.031423
# Q92536   0.034951  0.085437  0.058252  0.089320  0.015534  0.038835
#
# [81 rows x 20 columns]

# %% [markdown]
# ### Independent test set

# %%
X, y, feature_names, sample_names = preprocess_pandas(
    df_aac, labels, return_names=True
)
(
    X_train,
    X_test,
    y_train,
    y_test,
    sample_names_train,
    sample_names_test,
) = get_independent_test_set(X, y, sample_names=sample_names, test_size=0.2)

# %% [markdown]
# ### Model selection

# %%
models_quick_compare(X_train, y_train)
# Out:
#                                                         0      1      2  \
# est
# GaussianNB()                                        0.764  0.764  0.567
# KNeighborsClassifier()                              0.615  0.458  0.567
# LinearSVC(class_weight='balanced', max_iter=100...  0.536  0.536  0.675
# LinearSVC(max_iter=1000000.0, random_state=0)       0.350  0.448  0.745
# RandomForestClassifier(class_weight='balanced',...  0.536  0.511  0.381
# RandomForestClassifier(random_state=0)              0.615  0.511  0.381
# SGDClassifier(random_state=0)                       0.350  0.606  0.639
# SVC(class_weight='balanced', random_state=0)        0.512  0.575  0.567
# SVC(random_state=0)                                 0.675  0.458  0.567
#
#                                                         3      4   mean    std
# est
# GaussianNB()                                        0.462  0.486  0.608  0.147
# KNeighborsClassifier()                              0.513  0.829  0.596  0.143
# LinearSVC(class_weight='balanced', max_iter=100...  0.536  0.486  0.554  0.071
# LinearSVC(max_iter=1000000.0, random_state=0)       0.536  0.438  0.503  0.150
# RandomForestClassifier(class_weight='balanced',...  0.536  0.556  0.504  0.070
# RandomForestClassifier(random_state=0)              0.536  0.625  0.534  0.099
# SGDClassifier(random_state=0)                       0.536  0.333  0.493  0.143
# SVC(class_weight='balanced', random_state=0)        0.462  0.667  0.557  0.077
# SVC(random_state=0)                                 0.405  0.697  0.561  0.129

# %% [markdown]
# ### Parameter tuning
#
# RBF kernel delivers slightly better results

# %%
gsearch = optimize_hyperparams(X_train, y_train, kernel="linear", dim_reduction=None)
# Out:
# {'linearsvc__C': 0.1, 'linearsvc__class_weight': None, 'linearsvc__dual': True, 'linearsvc__max_iter': 100000000.0}
# 0.556

# %%
gsearch = optimize_hyperparams(X_train, y_train, kernel="rbf", dim_reduction=None, C=[1,0.1,10])
best_estimator_svc = gsearch
# Out:
# {'svc__C': 1, 'svc__class_weight': 'balanced', 'svc__gamma': 0.01}
# 0.624

# %% [markdown]
# ### Dimensionality reduction

# %% [markdown]
# Kbest performs slightly better:

# %%
gsearch = optimize_hyperparams(
    X_train, y_train, kernel="rbf", dim_reduction="kbest"#, C=[1,10,100], gamma=["scale"]
)
best_estimator_svc_kbest = gsearch
# Out:
# {'selectkbest__k': 3, 'svc__C': 10, 'svc__class_weight': 'balanced', 'svc__gamma': 0.01}
# 0.664

# %% [markdown]
# PCA improves the results a bit more_

# %%
gsearch = optimize_hyperparams(
    X_train,
    y_train,
    kernel="rbf",
    dim_reduction="pca",
    # C=[1, 10, 100],
    # gamma=["scale", 0.1, 0.01, 0.001],
)
best_estimator_svc_pca = gsearch
# Out:
# {'pca__n_components': 0.94, 'svc__C': 10, 'svc__class_weight': 'balanced', 'svc__gamma': 'scale'}
# 0.659

# %% [markdown]
# ### Validation
#
# The test set is only made up of 10 amino and 7 sugar transporters, so one miss-classification can already change the score by quite a large amount. The sample count does not seem to be enough for a good model.
#
# The PCA model seems to lead to less overfitting, having better scores on the test set.

# %%
get_confusion_matrix(X_test, y_test, best_estimator_svc_kbest, labels=labels)
# Out:
# predicted             Amino-acid transport  Sugar transport
# observed
# Amino-acid transport                     6                4
# Sugar transport                          2                5

# %%
get_classification_report(X_test, y_test, best_estimator_svc_kbest, labels=labels)
# Out:
#                       precision  recall  f1-score  support
# Amino-acid transport      0.750   0.600     0.667       10
# Sugar transport           0.556   0.714     0.625        7
# macro avg                 0.653   0.657     0.646       17
# weighted avg              0.670   0.647     0.650       17

# %%
get_confusion_matrix(X_test, y_test, best_estimator_svc_pca, labels=labels)
# Out:
# predicted             Amino-acid transport  Sugar transport
# observed
# Amino-acid transport                     8                2
# Sugar transport                          2                5

# %%
get_classification_report(X_test, y_test, best_estimator_svc_pca, labels=labels)
# Out:
#                       precision  recall  f1-score  support
# Amino-acid transport      0.800   0.800     0.800       10
# Sugar transport           0.714   0.714     0.714        7
# macro avg                 0.757   0.757     0.757       17
# weighted avg              0.765   0.765     0.765       17

# %% [markdown]
# ## Checking dependence on train test split
#
# Especially the performance of the sugar transporter test set is not good, it's the class with the fewest number of samples

# %% [markdown]
# #### PCA model:
#
# The average model performance does not improve with other train test splits:

# %%
df_scores, df_params = full_test(
    df_aac, labels, dim_reduction="pca", kernel="rbf", repetitions=10
)
display(
    df_scores.groupby(["label", "dataset"], as_index=False)
    .mean()
    .pivot(index="label", columns="dataset", values="F1 score")
)
display(
    df_scores.groupby(["label", "dataset"], as_index=False)
    .std()
    .pivot(index="label", columns="dataset", values="F1 score")
)
# Out:
# dataset                 test   train
# label
# Amino-acid transport  0.7273  0.8137
# Sugar transport       0.5766  0.7316
# dataset                   test     train
# label
# Amino-acid transport  0.107377  0.040288
# Sugar transport       0.168679  0.082974

# %% [markdown]
# #### Kbest
#
# The same is true for kbest:

# %%
df_scores, df_params = full_test(
    df_aac, labels, dim_reduction="kbest", kernel="rbf", repetitions=10
)
display(
    df_scores.groupby(["label", "dataset"], as_index=False)
    .mean()
    .pivot(index="label", columns="dataset", values="F1 score")
)
display(
    df_scores.groupby(["label", "dataset"], as_index=False)
    .std()
    .pivot(index="label", columns="dataset", values="F1 score")
)
# Out:
# dataset                 test   train
# label
# Amino-acid transport  0.7324  0.8426
# Sugar transport       0.5921  0.7394
# dataset                   test     train
# label
# Amino-acid transport  0.102300  0.075029
# Sugar transport       0.146802  0.101609

# %% [markdown]
# ## LOOCV
#
# To increase the number of samples availale for training, we carry out a nested leave one out cross validation:

# %%
df_scores, df_params = full_test(
    df_aac, labels, dim_reduction="pca", kernel="rbf", repetitions=10, cross_val_method="loocv"
)
display(
    df_scores.groupby(["label", "dataset"], as_index=False)
    .mean()
    .pivot(index="label", columns="dataset", values="F1 score")
)
display(
    df_scores.groupby(["label", "dataset"], as_index=False)
    .std()
    .pivot(index="label", columns="dataset", values="F1 score")
)
# Out:
# dataset                 test   train
# label
# Amino-acid transport  0.7184  0.8587
# Sugar transport       0.5211  0.7627
# dataset                   test     train
# label
# Amino-acid transport  0.080949  0.067067
# Sugar transport       0.139697  0.115330

# %%
df_params
# Out:
#                           0         1         2         3         4         5  \
# pca__n_components       0.8      0.91      0.84      0.96       0.9      0.84
# svc__C                    1         1        10         1        10         1
# svc__class_weight  balanced  balanced  balanced  balanced  balanced  balanced
# svc__gamma            scale       0.1      0.01      0.01     scale       0.1
#
#                        6      7     8         9
# pca__n_components   0.84   0.82  0.87      0.87
# svc__C             10.00      1  1.00         1
# svc__class_weight    NaN   None   NaN  balanced
# svc__gamma          0.01  scale  0.10       0.1

# %% [markdown]
# With LOOCV, there is a slight improvement in average F1 scores and their standard deviations. It becomes clear that AAC alone is not suitable for this classification task.

# %%
df_scores, df_params = full_test(
    df_aac, labels, dim_reduction="kbest", kernel="rbf", repetitions=10, cross_val_method="loocv"
)
display(
    df_scores.groupby(["label", "dataset"], as_index=False)
    .mean()
    .pivot(index="label", columns="dataset", values="F1 score")
)
display(
    df_scores.groupby(["label", "dataset"], as_index=False)
    .std()
    .pivot(index="label", columns="dataset", values="F1 score")
)
# Out:
# dataset                 test   train
# label
# Amino-acid transport  0.6965  0.8873
# Sugar transport       0.5266  0.8102
# dataset                   test     train
# label
# Amino-acid transport  0.117582  0.070659
# Sugar transport       0.201974  0.100418

# %% [markdown]
# ## Without Sideroflexin
#
# Does removing the Sideroflexin proteins improve classification performance?

# %%
mask_sideroflexin = ~df.protein_names.str.startswith("Side")
df_scores, df_params = full_test(
    df_aac.loc[mask_sideroflexin],
    labels.loc[mask_sideroflexin],
    dim_reduction="pca",
    kernel="rbf",
    repetitions=10,
    cross_val_method="loocv",
)
display(
    df_scores.groupby(["label", "dataset"], as_index=False)
    .mean()
    .pivot(index="label", columns="dataset", values="F1 score")
)
display(
    df_scores.groupby(["label", "dataset"], as_index=False)
    .std()
    .pivot(index="label", columns="dataset", values="F1 score")
)
df_params
# Out:
# dataset                 test   train
# label
# Amino-acid transport  0.7428  0.8386
# Sugar transport       0.5839  0.7523
# dataset                   test     train
# label
# Amino-acid transport  0.046621  0.042636
# Sugar transport       0.133887  0.074288
#                        0         1      2         3         4    5         6  \
# pca__n_components   0.94      0.98    0.8       0.8      0.93  0.8      0.83
# svc__C             10.00        10      1         1        10  1.0        10
# svc__class_weight    NaN  balanced   None  balanced  balanced  NaN  balanced
# svc__gamma          0.01      0.01  scale     scale     scale  0.1      0.01
#
#                           7         8      9
# pca__n_components      0.89      0.84   0.97
# svc__C                   10        10  10.00
# svc__class_weight  balanced  balanced    NaN
# svc__gamma             0.01     scale   0.01

# %% [markdown]
# No, removing these proteins does not make much of a difference. They only occurred in the PCA of PAAC anyway.
