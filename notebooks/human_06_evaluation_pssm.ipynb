# %% [markdown]
# # PSSM Feature evaluation

# %% [markdown]
# # Imports

# %%
from subpred.transporter_dataset import create_dataset
from subpred.eval import (
    get_independent_test_set,
    optimize_hyperparams,
    preprocess_pandas,
    models_quick_compare,
    get_confusion_matrix,
    get_classification_report,
    full_test,
)
from subpred.pssm import calculate_pssms_notebook

# %% [markdown]
# # Dataset

# %%
df = create_dataset(
    keywords_substrate_filter = ["Amino-acid transport","Sugar transport"],
    keywords_component_filter = ["Transmembrane"],
    keywords_transport_filter = ["Transport"],
    input_file = "../data/raw/swissprot/uniprot-reviewed_yes.tab.gz",
    multi_substrate = "integrate",
    verbose = True,
    tax_ids_filter = [9606],
    output_log = "../logs/human_amino_sugar_dataset.log",
    outliers=["Q9HBR0", "Q07837"],
    sequence_clustering=70
)
# Out:
# cd-hit: clustered 85 sequences into 81 clusters at threshold 70

# %% [markdown]
# # Feature generation

# %%
labels = df.keywords_transport
labels.value_counts()
# Out:
# Amino-acid transport    48
# Sugar transport         33
# Name: keywords_transport, dtype: int64

# %%
df_pssm = calculate_pssms_notebook(df.sequence)
df_pssm
# Out:
#           AA_50_1   AR_50_1   AN_50_1   AD_50_1   AC_50_1   AQ_50_1   AE_50_1  \
# Uniprot
# Q9BRV3   0.676768  0.488215  0.508418  0.464646  0.602694  0.511785  0.478114
# Q5M8T2   0.812672  0.363636  0.407713  0.314050  0.595041  0.451791  0.399449
# Q969S0   0.638989  0.339350  0.418773  0.342960  0.494585  0.404332  0.357401
# O75387   0.698152  0.441478  0.455852  0.418891  0.523614  0.447639  0.439425
# Q9NTN3   0.808333  0.325000  0.350000  0.283333  0.591667  0.416667  0.362500
# ...           ...       ...       ...       ...       ...       ...       ...
# Q96A29   0.696023  0.485795  0.480114  0.443182  0.511364  0.502841  0.465909
# Q9BYW1   0.786749  0.343685  0.418219  0.316770  0.610766  0.455487  0.383023
# P14672   0.808300  0.316206  0.418972  0.332016  0.600791  0.409091  0.363636
# Q96AA3   0.711697  0.449753  0.462932  0.393740  0.566722  0.481054  0.429984
# Q92536   0.800000  0.343243  0.351351  0.278378  0.556757  0.354054  0.327027
#
#           AG_50_1   AH_50_1   AI_50_1  ...   VL_90_3   VK_90_3   VM_90_3  \
# Uniprot                                ...
# Q9BRV3   0.565657  0.511785  0.612795  ...  0.484375  0.403125  0.471875
# Q5M8T2   0.498623  0.407713  0.539945  ...  0.522388  0.492537  0.525373
# Q969S0   0.498195  0.382671  0.454874  ...  0.492669  0.398827  0.492669
# O75387   0.558522  0.472279  0.474333  ...  0.527546  0.510851  0.509182
# Q9NTN3   0.504167  0.412500  0.500000  ...  0.450704  0.357746  0.439437
# ...           ...       ...       ...  ...       ...       ...       ...
# Q96A29   0.559659  0.477273  0.500000  ...  0.547126  0.457471  0.531034
# Q9BYW1   0.546584  0.424431  0.498965  ...  0.534107  0.502177  0.528302
# P14672   0.551383  0.371542  0.503953  ...  0.514116  0.476969  0.505201
# Q96AA3   0.528830  0.434926  0.546952  ...  0.571069  0.500629  0.555975
# Q92536   0.581081  0.310811  0.483784  ...  0.462547  0.425094  0.460674
#
#           VF_90_3   VP_90_3   VS_90_3   VT_90_3   VW_90_3   VY_90_3   VV_90_3
# Uniprot
# Q9BRV3   0.706250  0.368750  0.443750  0.440625  0.568750  0.856250  0.478125
# Q5M8T2   0.659701  0.498507  0.516418  0.513433  0.594030  0.817910  0.498507
# Q969S0   0.568915  0.384164  0.422287  0.416422  0.609971  0.750733  0.472141
# O75387   0.602671  0.477462  0.514190  0.515860  0.544240  0.686144  0.512521
# Q9NTN3   0.645070  0.321127  0.388732  0.397183  0.594366  0.867606  0.450704
# ...           ...       ...       ...       ...       ...       ...       ...
# Q96A29   0.655172  0.427586  0.487356  0.482759  0.634483  0.749425  0.533333
# Q9BYW1   0.647315  0.489115  0.516691  0.513788  0.579100  0.718433  0.523948
# P14672   0.618128  0.471025  0.490342  0.484398  0.551263  0.716196  0.494799
# Q96AA3   0.640252  0.483019  0.529560  0.515723  0.571069  0.739623  0.544654
# Q92536   0.597378  0.376404  0.425094  0.423221  0.528090  0.820225  0.458801
#
# [81 rows x 1600 columns]

# %% [markdown]
# ## Independent test set

# %%
X, y, feature_names, sample_names = preprocess_pandas(
    df_pssm, labels, return_names=True
)
(
    X_train,
    X_test,
    y_train,
    y_test,
    sample_names_train,
    sample_names_test,
) = get_independent_test_set(X, y, sample_names=sample_names, test_size=0.2)

# %% [markdown]
# ## Model comparison
#
# Linear SVC looks promising before feature selection, more so than RBF. Could be that the linear kernel prevents overfitting, due to the many features and few samples.

# %%
models_quick_compare(X_train, y_train)
# Out:
#                                                         0      1      2  \
# est
# GaussianNB()                                        0.845  0.606  0.575
# KNeighborsClassifier()                              0.921  0.675  0.567
# LinearSVC(class_weight='balanced', max_iter=100...  0.845  0.745  0.819
# LinearSVC(max_iter=1000000.0, random_state=0)       0.845  0.745  0.819
# RandomForestClassifier(class_weight='balanced',...  0.745  0.606  0.381
# RandomForestClassifier(random_state=0)              0.745  0.675  0.381
# SGDClassifier(random_state=0)                       0.845  0.764  0.707
# SVC(class_weight='balanced', random_state=0)        0.921  0.606  0.567
# SVC(random_state=0)                                 0.745  0.606  0.381
#
#                                                         3      4   mean    std
# est
# GaussianNB()                                        0.606  0.748  0.676  0.116
# KNeighborsClassifier()                              0.675  0.916  0.751  0.159
# LinearSVC(class_weight='balanced', max_iter=100...  0.690  0.829  0.786  0.066
# LinearSVC(max_iter=1000000.0, random_state=0)       0.690  0.829  0.786  0.066
# RandomForestClassifier(class_weight='balanced',...  0.769  0.833  0.667  0.180
# RandomForestClassifier(random_state=0)              0.690  0.916  0.682  0.193
# SGDClassifier(random_state=0)                       0.606  0.748  0.734  0.087
# SVC(class_weight='balanced', random_state=0)        0.690  0.916  0.740  0.169
# SVC(random_state=0)                                 0.769  0.916  0.683  0.202

# %% [markdown]
# ## Parameter tuning

# %% [markdown]
# #### Custom transformer
#
# Here, we try the multi-pssm feature, which tries all combinations of feature generation parameters, and selects the best ones based on the training set. First without the transformer:

# %%
gsearch = optimize_hyperparams(
    X_train,
    y_train,
    kernel="linear",
    dim_reduction=None,
    C=[1, 10, 100],
)
# Out:
# {'linearsvc__C': 10, 'linearsvc__class_weight': 'balanced', 'linearsvc__dual': False, 'linearsvc__max_iter': 100000000.0}
# 0.808

# %% [markdown]
# The linear kernel already leads to good results. With the transformer:

# %%
gsearch = optimize_hyperparams(
    X_train,
    y_train,
    kernel="linear",
    dim_reduction=None,
    feature_transformer="pssm", 
    feature_names = feature_names,
    C=[0.001, 0.01, 0.1, 1]
)
best_estimator_linear = gsearch
# Out:
# {'linearsvc__C': 0.01, 'linearsvc__class_weight': 'balanced', 'linearsvc__dual': True, 'linearsvc__max_iter': 100000000.0, 'pssmselector__iterations': 'all', 'pssmselector__uniref_threshold': 50}
# 0.823

# %% [markdown]
# Lower value of C, better results. Does RBF improve anything?

# %%
gsearch = optimize_hyperparams(
    X_train,
    y_train,
    kernel="rbf",
    dim_reduction=None,
    C=[1, 10, 100],
)
# Out:
# {'svc__C': 10, 'svc__class_weight': 'balanced', 'svc__gamma': 'scale'}
# 0.766

# %% [markdown]
# In contrast to A Thaliana, we get lower scores with the RBF kernel without feature reduction. With the feature selector:

# %%
gsearch = optimize_hyperparams(
    X_train,
    y_train,
    kernel="rbf",
    dim_reduction=None,
    C=[1, 10, 100],
    feature_transformer="pssm",
    feature_names=feature_names,
)
# Out:
# {'pssmselector__iterations': 1, 'pssmselector__uniref_threshold': 50, 'svc__C': 10, 'svc__class_weight': 'balanced', 'svc__gamma': 'scale'}
# 0.903

# %% [markdown]
# RBF with feature selector is the best one so far.

# %% [markdown]
# ## Dimensionality reduction

# %% [markdown]
# With PCA and the linear kernel, the results are slightly worse than for rbf with no FS

# %%
gsearch = optimize_hyperparams(
    X_train,
    y_train,
    kernel="linear",
    dim_reduction="pca",
    C=[1, 0.1, 0.001, 0.01],
    feature_transformer="pssm",
    feature_names=feature_names,
)
best_estimator_linearsvc_pca = gsearch
# Out:
# {'linearsvc__C': 1, 'linearsvc__class_weight': 'balanced', 'linearsvc__dual': True, 'linearsvc__max_iter': 100000000.0, 'pca__n_components': 0.94, 'pssmselector__iterations': 1, 'pssmselector__uniref_threshold': 50}
# 0.871

# %% [markdown]
# Without the pssm selection, we get lower results:

# %%
gsearch = optimize_hyperparams(
    X_train,
    y_train,
    kernel="linear",
    dim_reduction="pca",
    # C=[0.001, 0.01, 0.1],
)
# Out:
# {'linearsvc__C': 0.1, 'linearsvc__class_weight': 'balanced', 'linearsvc__dual': True, 'linearsvc__max_iter': 100000000.0, 'pca__n_components': 0.99}
# 0.803

# %% [markdown]
# PCA seems to perform the best and is faster, how about the RBF kernel?

# %%
gsearch = optimize_hyperparams(
    X_train,
    y_train,
    kernel="rbf",
    dim_reduction="pca",
    C=[1, 10, 100],
    # gamma=["scale"],
)
# Out:
# {'pca__n_components': 0.92, 'svc__C': 10, 'svc__class_weight': 'balanced', 'svc__gamma': 'scale'}
# 0.855

# %% [markdown]
# With the custom transformer, rbf and pca, we get the best training score. Lower values of gamma lead to higher scores on the training set, but possibly also more overfitting. Setting gamma to scale only:

# %%
gsearch = optimize_hyperparams(
    X_train,
    y_train,
    kernel="rbf",
    dim_reduction="pca",
    feature_transformer="pssm",
    feature_names=feature_names,
    C=[1, 0.1, 10],
    gamma=["scale"],
)
best_estimator_svc_pca = gsearch
# Out:
# {'pca__n_components': 0.9299999999999999, 'pssmselector__iterations': 'all', 'pssmselector__uniref_threshold': 50, 'svc__C': 1, 'svc__class_weight': 'balanced', 'svc__gamma': 'scale'}
# 0.936

# %% [markdown]
# ## Validation

# %% [markdown]
# ### Linear kernel without feature selection
#
# With just the linear kernel and the pssmselector, we get a perfect score on the training set. That might be due to chance, which we will evaluate later

# %%
get_confusion_matrix(X_test, y_test, best_estimator_linear, labels=labels)
# Out:
# predicted             Amino-acid transport  Sugar transport
# observed
# Amino-acid transport                    10                0
# Sugar transport                          0                7

# %%
get_classification_report(X_test, y_test, best_estimator_linear, labels=labels)
# Out:
#                       precision  recall  f1-score  support
# Amino-acid transport        1.0     1.0       1.0       10
# Sugar transport             1.0     1.0       1.0        7
# macro avg                   1.0     1.0       1.0       17
# weighted avg                1.0     1.0       1.0       17

# %% [markdown]
# ### Linear kernel with PCA
#
# Adding PCA leads to one wrong classification:

# %%
get_confusion_matrix(X_test, y_test, best_estimator_linearsvc_pca, labels=labels)
# Out:
# predicted             Amino-acid transport  Sugar transport
# observed
# Amino-acid transport                     9                1
# Sugar transport                          0                7

# %%
get_classification_report(X_test, y_test, best_estimator_linearsvc_pca, labels=labels)
# Out:
#                       precision  recall  f1-score  support
# Amino-acid transport      1.000   0.900     0.947       10
# Sugar transport           0.875   1.000     0.933        7
# macro avg                 0.938   0.950     0.940       17
# weighted avg              0.949   0.941     0.942       17

# %% [markdown]
# ### RBF + PCA
#
# RBF kernel and pca leads to a perfect score again.

# %%
get_confusion_matrix(X_test, y_test, best_estimator_svc_pca, labels=labels)
# Out:
# predicted             Amino-acid transport  Sugar transport
# observed
# Amino-acid transport                    10                0
# Sugar transport                          0                7

# %%
get_classification_report(X_test, y_test, best_estimator_svc_pca, labels=labels)
# Out:
#                       precision  recall  f1-score  support
# Amino-acid transport        1.0     1.0       1.0       10
# Sugar transport             1.0     1.0       1.0        7
# macro avg                   1.0     1.0       1.0       17
# weighted avg                1.0     1.0       1.0       17

# %% [markdown]
# ## Estimating validation variance
#
# How much did the result depend on choosing the training and test sets?
#
# Mean and standard deviation for randomly selected training and validation sets.

# %% [markdown]
# #### RBF+PCA

# %%
df_scores, df_params = full_test(
    df_pssm,
    labels,
    dim_reduction="pca",
    kernel="rbf",
    repetitions=10,
    feature_transformer="pssm",
)
df_scores_gr = df_scores.groupby(["label", "dataset"], as_index=False)
print("Mean F1")
display(df_scores_gr.mean().pivot(index="label", columns="dataset", values="F1 score"))
print("Sdev F1")
display(df_scores_gr.std().pivot(index="label", columns="dataset", values="F1 score"))
print("Parameters")
display(df_params)
# Out:
# Mean F1
# dataset                 test   train
# label
# Amino-acid transport  0.8752  0.9445
# Sugar transport       0.7965  0.9194
# Sdev F1
# dataset                   test     train
# label
# Amino-acid transport  0.063822  0.013083
# Sugar transport       0.113128  0.021025
# Parameters
#                                        0         1         2         3      4  \
# pca__n_components                   0.94      0.92      0.89      0.99   0.92
# pssmselector__iterations               3         3       all         3    all
# pssmselector__uniref_threshold        50        50       all       all     50
# svc__C                                 1        10        10         1      1
# svc__class_weight               balanced  balanced  balanced  balanced   None
# svc__gamma                           0.1       0.1       0.1     scale  scale
#
#                                    5         6      7         8         9
# pca__n_components               0.94      0.93   0.95      0.91      0.88
# pssmselector__iterations         all       all      1       all         1
# pssmselector__uniref_threshold    50        50     50        50        90
# svc__C                             1         1      1        10         1
# svc__class_weight               None  balanced   None  balanced  balanced
# svc__gamma                       0.1       0.1  scale     scale       0.1

# %% [markdown]
# Very good results for the cross validation on the training set, but again not so much on the test set, especially for sugar. This could be caused by the very low sample count.

# %% [markdown]
# #### Just the linear kernel and PSSMselector

# %%
df_scores, df_params = full_test(
    df_pssm,
    labels,
    kernel="linear",
    repetitions=10,
    feature_transformer="pssm",
    cross_val_method="5fold"
)
df_scores_gr = df_scores.groupby(["label", "dataset"], as_index=False)
print("Mean F1")
display(df_scores_gr.mean().pivot(index="label", columns="dataset", values="F1 score"))
print("Sdev F1")
display(df_scores_gr.std().pivot(index="label", columns="dataset", values="F1 score"))
print("Parameters")
display(df_params)
# Out:
# Mean F1
# dataset                 test   train
# label
# Amino-acid transport  0.8676  0.8930
# Sugar transport       0.8127  0.8542
# Sdev F1
# dataset                   test     train
# label
# Amino-acid transport  0.056884  0.023636
# Sugar transport       0.098688  0.034676
# Parameters
#                                           0            1            2  \
# linearsvc__C                             10           10            1
# linearsvc__class_weight                None     balanced     balanced
# linearsvc__dual                       False        False         True
# linearsvc__max_iter             100000000.0  100000000.0  100000000.0
# pssmselector__iterations                  3            3          all
# pssmselector__uniref_threshold          all          all           50
#
#                                           3            4            5  \
# linearsvc__C                             10            1            1
# linearsvc__class_weight                None     balanced     balanced
# linearsvc__dual                       False         True         True
# linearsvc__max_iter             100000000.0  100000000.0  100000000.0
# pssmselector__iterations                  3          all          all
# pssmselector__uniref_threshold          all           50           50
#
#                                           6            7            8  \
# linearsvc__C                              1            1          0.1
# linearsvc__class_weight            balanced     balanced     balanced
# linearsvc__dual                        True         True         True
# linearsvc__max_iter             100000000.0  100000000.0  100000000.0
# pssmselector__iterations                all            3            1
# pssmselector__uniref_threshold           50           50           50
#
#                                           9
# linearsvc__C                             10
# linearsvc__class_weight            balanced
# linearsvc__dual                       False
# linearsvc__max_iter             100000000.0
# pssmselector__iterations                  3
# pssmselector__uniref_threshold           50

# %% [markdown]
# The linear SVM leads to a more stable model overall. How does the higher number of training samples in LOOCV change the evaluation results?

# %%
df_scores, df_params = full_test(
    df_pssm,
    labels,
    kernel="linear",
    repetitions=10,
    feature_transformer="pssm",
    cross_val_method="loocv"
)
df_scores_gr = df_scores.groupby(["label", "dataset"], as_index=False)
print("Mean F1")
display(df_scores_gr.mean().pivot(index="label", columns="dataset", values="F1 score"))
print("Sdev F1")
display(df_scores_gr.std().pivot(index="label", columns="dataset", values="F1 score"))
print("Parameters")
display(df_params)
# Out:
# Mean F1
# dataset                 test   train
# label
# Amino-acid transport  0.8553  0.8979
# Sugar transport       0.8013  0.8582
# Sdev F1
# dataset                   test     train
# label
# Amino-acid transport  0.036179  0.021388
# Sugar transport       0.059922  0.029484
# Parameters
#                                           0            1            2  \
# linearsvc__C                              1            1            1
# linearsvc__class_weight            balanced     balanced     balanced
# linearsvc__dual                        True         True         True
# linearsvc__max_iter             100000000.0  100000000.0  100000000.0
# pssmselector__iterations                  3          all            3
# pssmselector__uniref_threshold          all          all           50
#
#                                           3            4            5  \
# linearsvc__C                             10            1           10
# linearsvc__class_weight            balanced     balanced     balanced
# linearsvc__dual                       False         True        False
# linearsvc__max_iter             100000000.0  100000000.0  100000000.0
# pssmselector__iterations                all            3          all
# pssmselector__uniref_threshold          all          all           90
#
#                                           6            7            8  \
# linearsvc__C                              1           10            1
# linearsvc__class_weight            balanced         None     balanced
# linearsvc__dual                        True        False         True
# linearsvc__max_iter             100000000.0  100000000.0  100000000.0
# pssmselector__iterations                all            3            3
# pssmselector__uniref_threshold           50           50           50
#
#                                           9
# linearsvc__C                              1
# linearsvc__class_weight            balanced
# linearsvc__dual                        True
# linearsvc__max_iter             100000000.0
# pssmselector__iterations                  3
# pssmselector__uniref_threshold          all

# %% [markdown]
# In this case, LOOCV does not make a difference. Does PCA improve the model?

# %% [markdown]
# #### PCA + linear Kernel

# %%
df_scores, df_params = full_test(
    df_pssm,
    labels,
    dim_reduction="pca",
    kernel="linear",
    repetitions=10,
    feature_transformer="pssm",
)
df_scores_gr = df_scores.groupby(["label", "dataset"], as_index=False)
print("Mean F1")
display(df_scores_gr.mean().pivot(index="label", columns="dataset", values="F1 score"))
print("Sdev F1")
display(df_scores_gr.std().pivot(index="label", columns="dataset", values="F1 score"))
print("Parameters")
display(df_params)
# Out:
# Mean F1
# dataset                 test   train
# label
# Amino-acid transport  0.8422  0.9049
# Sugar transport       0.7601  0.8668
# Sdev F1
# dataset                   test     train
# label
# Amino-acid transport  0.040080  0.027225
# Sugar transport       0.087827  0.038640
# Parameters
#                                           0            1            2  \
# linearsvc__C                            0.1            1          0.1
# linearsvc__class_weight                None     balanced         None
# linearsvc__dual                        True         True         True
# linearsvc__max_iter             100000000.0  100000000.0  100000000.0
# pca__n_components                      0.97         0.99         0.99
# pssmselector__iterations                  3            3          all
# pssmselector__uniref_threshold          all          all           50
#
#                                           3            4            5  \
# linearsvc__C                              1          0.1           10
# linearsvc__class_weight            balanced     balanced     balanced
# linearsvc__dual                        True         True        False
# linearsvc__max_iter             100000000.0  100000000.0  100000000.0
# pca__n_components                      0.99         0.91         0.99
# pssmselector__iterations                  3          all            1
# pssmselector__uniref_threshold          all           50           50
#
#                                           6            7            8  \
# linearsvc__C                             10          0.1          0.1
# linearsvc__class_weight            balanced     balanced     balanced
# linearsvc__dual                        True         True         True
# linearsvc__max_iter             100000000.0  100000000.0  100000000.0
# pca__n_components                      0.98         0.98         0.94
# pssmselector__iterations                  3            3            3
# pssmselector__uniref_threshold           50           50           50
#
#                                           9
# linearsvc__C                              1
# linearsvc__class_weight            balanced
# linearsvc__dual                        True
# linearsvc__max_iter             100000000.0
# pca__n_components                      0.99
# pssmselector__iterations                  1
# pssmselector__uniref_threshold           50

# %% [markdown]
# PCA on the linear kernel leads to a bit more overfitting, not better results.

# %% [markdown]
# ## Additional dataset filtering
#
# Again, we try what effect removing the Sideroflexins has on the evaluation:

# %%
mask_sideroflexin = ~df.protein_names.str.startswith("Side")
df_scores, df_params = full_test(
    df_pssm.loc[mask_sideroflexin],
    labels.loc[mask_sideroflexin],
    dim_reduction="pca",
    kernel="rbf",
    repetitions=10,
    feature_transformer="pssm",
    # cross_val_method="loocv",
)
display(
    df_scores.groupby(["label", "dataset"], as_index=False)
    .mean()
    .pivot(index="label", columns="dataset", values="F1 score")
)
display(
    df_scores.groupby(["label", "dataset"], as_index=False)
    .std()
    .pivot(index="label", columns="dataset", values="F1 score")
)
df_params
# Out:
# dataset                 test   train
# label
# Amino-acid transport  0.8684  0.9357
# Sugar transport       0.8128  0.9137
# dataset                   test     train
# label
# Amino-acid transport  0.083295  0.026238
# Sugar transport       0.125424  0.035814
#                                    0         1         2         3         4  \
# pca__n_components                0.8      0.93       0.9      0.96      0.91
# pssmselector__iterations           3         3         3       all         1
# pssmselector__uniref_threshold    50        50        50        50        50
# svc__C                             1        10         1        10        10
# svc__class_weight               None  balanced  balanced  balanced  balanced
# svc__gamma                       0.1     scale     scale     scale       0.1
#
#                                        5         6         7         8  \
# pca__n_components                   0.93      0.88      0.99      0.87
# pssmselector__iterations               1         1         3       all
# pssmselector__uniref_threshold       all        50       all        50
# svc__C                                10        10         1        10
# svc__class_weight               balanced  balanced  balanced  balanced
# svc__gamma                         scale       0.1      0.01     scale
#
#                                        9
# pca__n_components                    0.9
# pssmselector__iterations               3
# pssmselector__uniref_threshold        50
# svc__C                                10
# svc__class_weight               balanced
# svc__gamma                           0.1

# %%
mask_sideroflexin = ~df.protein_names.str.startswith("Side")
df_scores, df_params = full_test(
    df_pssm.loc[mask_sideroflexin],
    labels.loc[mask_sideroflexin],
    # dim_reduction="pca",
    kernel="linear",
    repetitions=10,
    feature_transformer="pssm",
    # cross_val_method="loocv",
)
display(
    df_scores.groupby(["label", "dataset"], as_index=False)
    .mean()
    .pivot(index="label", columns="dataset", values="F1 score")
)
display(
    df_scores.groupby(["label", "dataset"], as_index=False)
    .std()
    .pivot(index="label", columns="dataset", values="F1 score")
)
df_params
# Out:
# dataset                 test   train
# label
# Amino-acid transport  0.8790  0.8742
# Sugar transport       0.8383  0.8388
# dataset                   test     train
# label
# Amino-acid transport  0.068751  0.026549
# Sugar transport       0.103488  0.031173
#                                           0            1            2  \
# linearsvc__C                             10           10           10
# linearsvc__class_weight            balanced     balanced     balanced
# linearsvc__dual                       False        False        False
# linearsvc__max_iter             100000000.0  100000000.0  100000000.0
# pssmselector__iterations                  1            1          all
# pssmselector__uniref_threshold           50          all           50
#
#                                           3            4            5  \
# linearsvc__C                            0.1            1            1
# linearsvc__class_weight                None     balanced     balanced
# linearsvc__dual                        True         True         True
# linearsvc__max_iter             100000000.0  100000000.0  100000000.0
# pssmselector__iterations                  1            1            3
# pssmselector__uniref_threshold           50          all          all
#
#                                           6            7            8  \
# linearsvc__C                             10           10            1
# linearsvc__class_weight            balanced     balanced     balanced
# linearsvc__dual                       False        False         True
# linearsvc__max_iter             100000000.0  100000000.0  100000000.0
# pssmselector__iterations                all            1            3
# pssmselector__uniref_threshold           50          all          all
#
#                                           9
# linearsvc__C                             10
# linearsvc__class_weight            balanced
# linearsvc__dual                        True
# linearsvc__max_iter             100000000.0
# pssmselector__iterations                  3
# pssmselector__uniref_threshold           50

# %% [markdown]
# In contrast to the PAAC feature, removing the sideroflexins did not make a difference to the classification performance. That makes sense, considering that these proteins outliers only in the PAAC PCA, not in that of PSSM and AAC.
