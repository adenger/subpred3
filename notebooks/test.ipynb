# %%
import sys

import pandas as pd

# sys.path.append("../src")
from subpred.transporter_dataset import create_dataset
from subpred.eval import full_test
from subpred.compositions import calculate_aac, calculate_paac
from subpred.pssm import calculate_pssms_notebook
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sodium = ["Q2UVJ5", "O04034", "Q9FKP1", "Q9LJI2", "Q9SYG9", "Q84TI7"]
gdu = ["O81775", "Q9SW07", "Q9FHH5", "Q8S8A0", "Q3E965", "Q3EAV6", "Q3E8L0"]
df_all = create_dataset(
    keywords_substrate_filter=[
        "Amino-acid transport",
        "Electron transport",
        "Sugar transport",
        "Potassium transport",
    ],
    keywords_component_filter=["Transmembrane"],
    keywords_transport_filter=["Transport"],
    input_file="../data/raw/swissprot/uniprot-reviewed_yes.tab",
    multi_substrate="integrate",
    outliers=gdu + sodium,
    verbose=True,
    tax_ids_filter=[3702],
    output_log="../logs/athaliana_amino_sugar_potassium.log",
    sequence_clustering=70,
)
# Out:
# cd-hit: clustered 297 sequences into 223 clusters at threshold 70

# %% [markdown]
# # Feature generation

# %%
df_aac = calculate_aac(df_all.sequence)
df_paac = calculate_paac(df_all.sequence)
df_pssm = calculate_pssms_notebook(df_all.sequence)
df_combined = pd.concat([df_aac, df_paac, df_pssm], axis=1)
labels = df_all.keywords_transport
labels.value_counts()
# Out:
# Sugar transport         84
# Electron transport      56
# Potassium transport     50
# Amino-acid transport    33
# Name: keywords_transport, dtype: int64

# %% [markdown]
# # Function

# %%
def test_case(df_features, labels: pd.Series, test_name: str, **kwargs):
    for dim_reduction in [None, "pca", "kbest"]:
        print("#" * 60)
        print("Feature reduction: ", dim_reduction)
        print("#" * 60)
        df_scores, df_params = full_test(
            df_features, labels, kernel="rbf", dim_reduction=dim_reduction, **kwargs
        )
        df_scores.label = df_scores.label.map(lambda x: x.replace(" transport", ""))

        display(df_params)
        df_scores_piv = df_scores.groupby(["label", "dataset"]).mean().unstack(1)
        df_scores_piv.loc["mean"] = df_scores_piv.mean()
        display(df_scores_piv.round(3))

        g = sns.barplot(data=df_scores, y="F1 score", x="label", hue="dataset")
        g.set_ylim((0, 1))
        g.set_xlabel("")
        plt.savefig(f"{test_name}_{dim_reduction}_barplot.png")
        plt.show()

        g = sns.boxplot(data=df_scores, y="F1 score", x="label", hue="dataset")
        g.set_xlabel("")
        g.set_ylim((0, 1))
        plt.savefig(f"{test_name}_{dim_reduction}_boxplot.png")
        plt.show()

# %% [markdown]
# # Eval AAC

# %%
test_case(
    df_aac,
    labels,
    test_name="AAC",
    decision_function_shape=["ovo"],
    gamma=["scale"],
    class_weight=["balanced"],
    C=[1, 10, 100],
)
# Out:
# ############################################################
# Feature reduction:  None
# ############################################################
#                                      0         1         2         3  \
# svc__C                              10         1        10       100
# svc__class_weight             balanced  balanced  balanced  balanced
# svc__decision_function_shape       ovo       ovo       ovo       ovo
# svc__gamma                       scale     scale     scale     scale
#
#                                      4         5         6         7  \
# svc__C                              10        10        10        10
# svc__class_weight             balanced  balanced  balanced  balanced
# svc__decision_function_shape       ovo       ovo       ovo       ovo
# svc__gamma                       scale     scale     scale     scale
#
#                                      8         9
# svc__C                               1         1
# svc__class_weight             balanced  balanced
# svc__decision_function_shape       ovo       ovo
# svc__gamma                       scale     scale
#            F1 score
# dataset        test  train
# label
# Amino-acid    0.697  0.794
# Electron      0.890  0.893
# Potassium     0.959  0.964
# Sugar         0.863  0.887
# mean          0.852  0.885
# ############################################################
# Feature reduction:  pca
# ############################################################
#                                      0         1         2         3  \
# pca__n_components                 0.91      0.99      0.94      0.96
# svc__C                               1         1        10        10
# svc__class_weight             balanced  balanced  balanced  balanced
# svc__decision_function_shape       ovo       ovo       ovo       ovo
# svc__gamma                       scale     scale     scale     scale
#
#                                      4         5         6         7  \
# pca__n_components                 0.96      0.99      0.99      0.85
# svc__C                              10        10         1        10
# svc__class_weight             balanced  balanced  balanced  balanced
# svc__decision_function_shape       ovo       ovo       ovo       ovo
# svc__gamma                       scale     scale     scale     scale
#
#                                      8         9
# pca__n_components                 0.96      0.93
# svc__C                              10        10
# svc__class_weight             balanced  balanced
# svc__decision_function_shape       ovo       ovo
# svc__gamma                       scale     scale
#            F1 score
# dataset        test  train
# label
# Amino-acid    0.673  0.770
# Electron      0.891  0.875
# Potassium     0.959  0.945
# Sugar         0.844  0.863
# mean          0.842  0.863
# ############################################################
# Feature reduction:  kbest
# ############################################################
#                                      0         1         2         3  \
# selectkbest__k                      18        19        18        18
# svc__C                              10         1         1        10
# svc__class_weight             balanced  balanced  balanced  balanced
# svc__decision_function_shape       ovo       ovo       ovo       ovo
# svc__gamma                       scale     scale     scale     scale
#
#                                      4         5         6         7  \
# selectkbest__k                      19        18        19        17
# svc__C                              10         1        10         1
# svc__class_weight             balanced  balanced  balanced  balanced
# svc__decision_function_shape       ovo       ovo       ovo       ovo
# svc__gamma                       scale     scale     scale     scale
#
#                                      8         9
# selectkbest__k                      13        19
# svc__C                              10        10
# svc__class_weight             balanced  balanced
# svc__decision_function_shape       ovo       ovo
# svc__gamma                       scale     scale
#            F1 score
# dataset        test  train
# label
# Amino-acid    0.675  0.815
# Electron      0.862  0.892
# Potassium     0.955  0.965
# Sugar         0.875  0.896
# mean          0.842  0.892

# %% [markdown]
# # Eval PAAC

# %%
test_case(df_paac, labels, test_name="PAAC",decision_function_shape=["ovo"], gamma=["scale"], C=[1,10,100], class_weight=["balanced"])
# Out:
# ############################################################
# Feature reduction:  None
# ############################################################
#                                      0         1         2         3  \
# svc__C                              10        10         1        10
# svc__class_weight             balanced  balanced  balanced  balanced
# svc__decision_function_shape       ovo       ovo       ovo       ovo
# svc__gamma                       scale     scale     scale     scale
#
#                                      4         5         6         7  \
# svc__C                              10        10        10        10
# svc__class_weight             balanced  balanced  balanced  balanced
# svc__decision_function_shape       ovo       ovo       ovo       ovo
# svc__gamma                       scale     scale     scale     scale
#
#                                      8         9
# svc__C                              10        10
# svc__class_weight             balanced  balanced
# svc__decision_function_shape       ovo       ovo
# svc__gamma                       scale     scale
#            F1 score
# dataset        test  train
# label
# Amino-acid    0.701  0.750
# Electron      0.892  0.867
# Potassium     0.951  0.918
# Sugar         0.883  0.885
# mean          0.857  0.855
# ############################################################
# Feature reduction:  pca
# ############################################################
#                                      0         1         2         3  \
# pca__n_components                 0.99      0.99      0.99      0.99
# svc__C                              10         1         1        10
# svc__class_weight             balanced  balanced  balanced  balanced
# svc__decision_function_shape       ovo       ovo       ovo       ovo
# svc__gamma                       scale     scale     scale     scale
#
#                                      4         5         6         7  \
# pca__n_components                 0.99       0.8      0.99      0.99
# svc__C                              10        10        10        10
# svc__class_weight             balanced  balanced  balanced  balanced
# svc__decision_function_shape       ovo       ovo       ovo       ovo
# svc__gamma                       scale     scale     scale     scale
#
#                                      8         9
# pca__n_components                 0.99      0.99
# svc__C                               1         1
# svc__class_weight             balanced  balanced
# svc__decision_function_shape       ovo       ovo
# svc__gamma                       scale     scale
#            F1 score
# dataset        test  train
# label
# Amino-acid    0.647  0.641
# Electron      0.542  0.586
# Potassium     0.852  0.784
# Sugar         0.790  0.770
# mean          0.708  0.695
# ############################################################
# Feature reduction:  kbest
# ############################################################
#                                      0         1         2         3  \
# selectkbest__k                     218       260       214       324
# svc__C                              10        10        10        10
# svc__class_weight             balanced  balanced  balanced  balanced
# svc__decision_function_shape       ovo       ovo       ovo       ovo
# svc__gamma                       scale     scale     scale     scale
#
#                                      4         5         6         7  \
# selectkbest__k                     267       232       192       348
# svc__C                              10        10        10        10
# svc__class_weight             balanced  balanced  balanced  balanced
# svc__decision_function_shape       ovo       ovo       ovo       ovo
# svc__gamma                       scale     scale     scale     scale
#
#                                      8         9
# selectkbest__k                     296       284
# svc__C                               1        10
# svc__class_weight             balanced  balanced
# svc__decision_function_shape       ovo       ovo
# svc__gamma                       scale     scale
#            F1 score
# dataset        test  train
# label
# Amino-acid    0.734  0.805
# Electron      0.884  0.886
# Potassium     0.955  0.925
# Sugar         0.884  0.904
# mean          0.864  0.880

# %% [markdown]
# # PSSM

# %%
test_case(
    df_pssm,
    labels,
    test_name="PSSM",
    decision_function_shape=["ovo"],
    gamma=["scale"],
    C=[1, 10, 100],
    class_weight=["balanced"],
    feature_filter="pssm",
    select_k_steps=10,
)
# Out:
# ############################################################
# Feature reduction:  None
# ############################################################
#                                        0         1         2         3  \
# pssmselector__iterations               1         1         1         1
# pssmselector__uniref_threshold        50        50        50        50
# svc__C                                10        10        10         1
# svc__class_weight               balanced  balanced  balanced  balanced
# svc__decision_function_shape         ovo       ovo       ovo       ovo
# svc__gamma                         scale     scale     scale     scale
#
#                                        4         5         6         7  \
# pssmselector__iterations               1         1         1         1
# pssmselector__uniref_threshold        50        50        50        50
# svc__C                                10        10        10        10
# svc__class_weight               balanced  balanced  balanced  balanced
# svc__decision_function_shape         ovo       ovo       ovo       ovo
# svc__gamma                         scale     scale     scale     scale
#
#                                        8         9
# pssmselector__iterations               1         1
# pssmselector__uniref_threshold        50        50
# svc__C                                10        10
# svc__class_weight               balanced  balanced
# svc__decision_function_shape         ovo       ovo
# svc__gamma                         scale     scale
#            F1 score
# dataset        test  train
# label
# Amino-acid    0.936  0.910
# Electron      0.987  0.979
# Potassium     0.995  0.982
# Sugar         0.977  0.959
# mean          0.974  0.957
# ############################################################
# Feature reduction:  pca
# ############################################################
#                                        0         1         2         3  \
# pca__n_components                   0.94      0.93      0.95      0.94
# pssmselector__iterations               1         1         1         1
# pssmselector__uniref_threshold        50        50        50        50
# svc__C                                10        10        10        10
# svc__class_weight               balanced  balanced  balanced  balanced
# svc__decision_function_shape         ovo       ovo       ovo       ovo
# svc__gamma                         scale     scale     scale     scale
#
#                                        4         5         6         7  \
# pca__n_components                   0.95      0.94      0.96      0.95
# pssmselector__iterations               1         1         1         1
# pssmselector__uniref_threshold        50        50        50        50
# svc__C                                10        10        10        10
# svc__class_weight               balanced  balanced  balanced  balanced
# svc__decision_function_shape         ovo       ovo       ovo       ovo
# svc__gamma                         scale     scale     scale     scale
#
#                                        8         9
# pca__n_components                   0.93      0.89
# pssmselector__iterations               1         1
# pssmselector__uniref_threshold        50        50
# svc__C                                10        10
# svc__class_weight               balanced  balanced
# svc__decision_function_shape         ovo       ovo
# svc__gamma                         scale     scale
#            F1 score
# dataset        test  train
# label
# Amino-acid    0.941  0.960
# Electron      0.980  0.975
# Potassium     0.995  0.986
# Sugar         0.963  0.974
# mean          0.970  0.974
# ############################################################
# Feature reduction:  kbest
# ############################################################
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/andy/subpred/notebooks/multi_substrate/athaliana_amino_sugar_potassium_electron_eval.ipynb Cell 12' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/andy/subpred/notebooks/multi_substrate/athaliana_amino_sugar_potassium_electron_eval.ipynb#ch0000009vscode-remote?line=0'>1</a> test_case(
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/andy/subpred/notebooks/multi_substrate/athaliana_amino_sugar_potassium_electron_eval.ipynb#ch0000009vscode-remote?line=1'>2</a>     df_pssm,
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/andy/subpred/notebooks/multi_substrate/athaliana_amino_sugar_potassium_electron_eval.ipynb#ch0000009vscode-remote?line=2'>3</a>     labels,
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/andy/subpred/notebooks/multi_substrate/athaliana_amino_sugar_potassium_electron_eval.ipynb#ch0000009vscode-remote?line=3'>4</a>     test_name="PSSM",
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/andy/subpred/notebooks/multi_substrate/athaliana_amino_sugar_potassium_electron_eval.ipynb#ch0000009vscode-remote?line=4'>5</a>     decision_function_shape=["ovo"],
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/andy/subpred/notebooks/multi_substrate/athaliana_amino_sugar_potassium_electron_eval.ipynb#ch0000009vscode-remote?line=5'>6</a>     gamma=["scale"],
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/andy/subpred/notebooks/multi_substrate/athaliana_amino_sugar_potassium_electron_eval.ipynb#ch0000009vscode-remote?line=6'>7</a>     C=[1, 10, 100],
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/andy/subpred/notebooks/multi_substrate/athaliana_amino_sugar_potassium_electron_eval.ipynb#ch0000009vscode-remote?line=7'>8</a>     class_weight=["balanced"],
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/andy/subpred/notebooks/multi_substrate/athaliana_amino_sugar_potassium_electron_eval.ipynb#ch0000009vscode-remote?line=8'>9</a>     feature_filter="pssm",
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/andy/subpred/notebooks/multi_substrate/athaliana_amino_sugar_potassium_electron_eval.ipynb#ch0000009vscode-remote?line=9'>10</a>     select_k_steps=10,
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/andy/subpred/notebooks/multi_substrate/athaliana_amino_sugar_potassium_electron_eval.ipynb#ch0000009vscode-remote?line=10'>11</a> )
#
# /home/andy/subpred/notebooks/multi_substrate/athaliana_amino_sugar_potassium_electron_eval.ipynb Cell 6' in test_case(df_features, labels, test_name, **kwargs)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/andy/subpred/notebooks/multi_substrate/athaliana_amino_sugar_potassium_electron_eval.ipynb#ch0000013vscode-remote?line=3'>4</a> print("Feature reduction: ", dim_reduction)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/andy/subpred/notebooks/multi_substrate/athaliana_amino_sugar_potassium_electron_eval.ipynb#ch0000013vscode-remote?line=4'>5</a> print("#" * 60)
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/andy/subpred/notebooks/multi_substrate/athaliana_amino_sugar_potassium_electron_eval.ipynb#ch0000013vscode-remote?line=5'>6</a> df_scores, df_params = full_test(
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/andy/subpred/notebooks/multi_substrate/athaliana_amino_sugar_potassium_electron_eval.ipynb#ch0000013vscode-remote?line=6'>7</a>     df_features, labels, kernel="rbf", dim_reduction=dim_reduction, **kwargs
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/andy/subpred/notebooks/multi_substrate/athaliana_amino_sugar_potassium_electron_eval.ipynb#ch0000013vscode-remote?line=7'>8</a> )
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/andy/subpred/notebooks/multi_substrate/athaliana_amino_sugar_potassium_electron_eval.ipynb#ch0000013vscode-remote?line=8'>9</a> df_scores.label = df_scores.label.map(lambda x: x.replace(" transport", ""))
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/andy/subpred/notebooks/multi_substrate/athaliana_amino_sugar_potassium_electron_eval.ipynb#ch0000013vscode-remote?line=10'>11</a> display(df_params)
#
# File ~/subpred/notebooks/multi_substrate/../../src/main/eval.py:213, in full_test(df_features, labels, repetitions, **kwargs)
#     <a href='file:///home/andy/subpred/notebooks/multi_substrate/../../src/main/eval.py?line=200'>201</a> for random_seed in range(repetitions):
#     <a href='file:///home/andy/subpred/notebooks/multi_substrate/../../src/main/eval.py?line=201'>202</a>     (
#     <a href='file:///home/andy/subpred/notebooks/multi_substrate/../../src/main/eval.py?line=202'>203</a>         X_train,
#     <a href='file:///home/andy/subpred/notebooks/multi_substrate/../../src/main/eval.py?line=203'>204</a>         X_test,
#    (...)
#     <a href='file:///home/andy/subpred/notebooks/multi_substrate/../../src/main/eval.py?line=209'>210</a>         X, y, sample_names, test_size=0.2, random_state=random_seed
#     <a href='file:///home/andy/subpred/notebooks/multi_substrate/../../src/main/eval.py?line=210'>211</a>     )
# --> <a href='file:///home/andy/subpred/notebooks/multi_substrate/../../src/main/eval.py?line=212'>213</a>     gsearch = optimize_hyperparams(
#     <a href='file:///home/andy/subpred/notebooks/multi_substrate/../../src/main/eval.py?line=213'>214</a>         X_train, y_train, verbose=False, feature_names=feature_names, **kwargs
#     <a href='file:///home/andy/subpred/notebooks/multi_substrate/../../src/main/eval.py?line=214'>215</a>     )
#     <a href='file:///home/andy/subpred/notebooks/multi_substrate/../../src/main/eval.py?line=215'>216</a>     df_params[random_seed] = pd.Series(gsearch.best_params_)
#     <a href='file:///home/andy/subpred/notebooks/multi_substrate/../../src/main/eval.py?line=216'>217</a>     best_estimator = gsearch.best_estimator_
#
# File ~/subpred/notebooks/multi_substrate/../../src/main/eval.py:138, in optimize_hyperparams(X_train, y_train, feature_filter, feature_names, kernel, C, gamma, class_weight, select_k_steps, dim_reduction, decision_function_shape, verbose)
#     <a href='file:///home/andy/subpred/notebooks/multi_substrate/../../src/main/eval.py?line=127'>128</a> pipe = make_pipeline(*pipe_list)
#     <a href='file:///home/andy/subpred/notebooks/multi_substrate/../../src/main/eval.py?line=128'>129</a> gsearch = GridSearchCV(
#     <a href='file:///home/andy/subpred/notebooks/multi_substrate/../../src/main/eval.py?line=129'>130</a>     estimator=pipe,
#     <a href='file:///home/andy/subpred/notebooks/multi_substrate/../../src/main/eval.py?line=130'>131</a>     param_grid=param_grid,
#    (...)
#     <a href='file:///home/andy/subpred/notebooks/multi_substrate/../../src/main/eval.py?line=135'>136</a>     refit=True,
#     <a href='file:///home/andy/subpred/notebooks/multi_substrate/../../src/main/eval.py?line=136'>137</a> )
# --> <a href='file:///home/andy/subpred/notebooks/multi_substrate/../../src/main/eval.py?line=137'>138</a> gsearch.fit(X_train, y_train)
#     <a href='file:///home/andy/subpred/notebooks/multi_substrate/../../src/main/eval.py?line=138'>139</a> if verbose:
#     <a href='file:///home/andy/subpred/notebooks/multi_substrate/../../src/main/eval.py?line=139'>140</a>     print(gsearch.best_params_)
#
# File ~/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py:891, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py?line=884'>885</a>     results = self._format_results(
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py?line=885'>886</a>         all_candidate_params, n_splits, all_out, all_more_results
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py?line=886'>887</a>     )
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py?line=888'>889</a>     return results
# --> <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py?line=890'>891</a> self._run_search(evaluate_candidates)
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py?line=892'>893</a> # multimetric is determined here because in the case of a callable
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py?line=893'>894</a> # self.scoring the return type is only known after calling
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py?line=894'>895</a> first_test_score = all_out[0]["test_scores"]
#
# File ~/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py:1392, in GridSearchCV._run_search(self, evaluate_candidates)
#    <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py?line=1389'>1390</a> def _run_search(self, evaluate_candidates):
#    <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py?line=1390'>1391</a>     """Search all candidates in param_grid"""
# -> <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py?line=1391'>1392</a>     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py:838, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py?line=829'>830</a> if self.verbose > 0:
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py?line=830'>831</a>     print(
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py?line=831'>832</a>         "Fitting {0} folds for each of {1} candidates,"
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py?line=832'>833</a>         " totalling {2} fits".format(
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py?line=833'>834</a>             n_splits, n_candidates, n_candidates * n_splits
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py?line=834'>835</a>         )
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py?line=835'>836</a>     )
# --> <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py?line=837'>838</a> out = parallel(
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py?line=838'>839</a>     delayed(_fit_and_score)(
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py?line=839'>840</a>         clone(base_estimator),
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py?line=840'>841</a>         X,
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py?line=841'>842</a>         y,
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py?line=842'>843</a>         train=train,
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py?line=843'>844</a>         test=test,
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py?line=844'>845</a>         parameters=parameters,
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py?line=845'>846</a>         split_progress=(split_idx, n_splits),
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py?line=846'>847</a>         candidate_progress=(cand_idx, n_candidates),
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py?line=847'>848</a>         **fit_and_score_kwargs,
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py?line=848'>849</a>     )
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py?line=849'>850</a>     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py?line=850'>851</a>         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py?line=851'>852</a>     )
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py?line=852'>853</a> )
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py?line=854'>855</a> if len(out) < 1:
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py?line=855'>856</a>     raise ValueError(
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py?line=856'>857</a>         "No fits were performed. "
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py?line=857'>858</a>         "Was the CV iterator empty? "
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py?line=858'>859</a>         "Were there no candidates?"
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/sklearn/model_selection/_search.py?line=859'>860</a>     )
#
# File ~/miniconda3/envs/subpred/lib/python3.9/site-packages/joblib/parallel.py:1056, in Parallel.__call__(self, iterable)
#    <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/joblib/parallel.py?line=1052'>1053</a>     self._iterating = False
#    <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/joblib/parallel.py?line=1054'>1055</a> with self._backend.retrieval_context():
# -> <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/joblib/parallel.py?line=1055'>1056</a>     self.retrieve()
#    <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/joblib/parallel.py?line=1056'>1057</a> # Make sure that we get a last message telling us we are done
#    <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/joblib/parallel.py?line=1057'>1058</a> elapsed_time = time.time() - self._start_time
#
# File ~/miniconda3/envs/subpred/lib/python3.9/site-packages/joblib/parallel.py:935, in Parallel.retrieve(self)
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/joblib/parallel.py?line=932'>933</a> try:
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/joblib/parallel.py?line=933'>934</a>     if getattr(self._backend, 'supports_timeout', False):
# --> <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/joblib/parallel.py?line=934'>935</a>         self._output.extend(job.get(timeout=self.timeout))
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/joblib/parallel.py?line=935'>936</a>     else:
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/joblib/parallel.py?line=936'>937</a>         self._output.extend(job.get())
#
# File ~/miniconda3/envs/subpred/lib/python3.9/site-packages/joblib/_parallel_backends.py:542, in LokyBackend.wrap_future_result(future, timeout)
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/joblib/_parallel_backends.py?line=538'>539</a> """Wrapper for Future.result to implement the same behaviour as
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/joblib/_parallel_backends.py?line=539'>540</a> AsyncResults.get from multiprocessing."""
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/joblib/_parallel_backends.py?line=540'>541</a> try:
# --> <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/joblib/_parallel_backends.py?line=541'>542</a>     return future.result(timeout=timeout)
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/joblib/_parallel_backends.py?line=542'>543</a> except CfTimeoutError as e:
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/site-packages/joblib/_parallel_backends.py?line=543'>544</a>     raise TimeoutError from e
#
# File ~/miniconda3/envs/subpred/lib/python3.9/concurrent/futures/_base.py:441, in Future.result(self, timeout)
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/concurrent/futures/_base.py?line=437'>438</a> elif self._state == FINISHED:
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/concurrent/futures/_base.py?line=438'>439</a>     return self.__get_result()
# --> <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/concurrent/futures/_base.py?line=440'>441</a> self._condition.wait(timeout)
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/concurrent/futures/_base.py?line=442'>443</a> if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/concurrent/futures/_base.py?line=443'>444</a>     raise CancelledError()
#
# File ~/miniconda3/envs/subpred/lib/python3.9/threading.py:312, in Condition.wait(self, timeout)
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/threading.py?line=309'>310</a> try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/threading.py?line=310'>311</a>     if timeout is None:
# --> <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/threading.py?line=311'>312</a>         waiter.acquire()
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/threading.py?line=312'>313</a>         gotit = True
#     <a href='file:///home/andy/miniconda3/envs/subpred/lib/python3.9/threading.py?line=313'>314</a>     else:
#
# KeyboardInterrupt:

# %% [markdown]
# # Combined

# %%
test_case(
    pd.concat([df_aac, df_paac, df_pssm], axis=1),
    labels,
    test_name="Combined",
    decision_function_shape=["ovo"],
    gamma=["scale"],
    C=[1, 10, 100],
    class_weight=["balanced"],
    feature_filter="pssm",
    select_k_steps=10,
)
