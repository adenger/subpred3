# %% [markdown]
# # AAC feature evaluation

# %% [markdown]
# # Imports

# %%
from subpred.transporter_dataset import create_dataset
from subpred.eval import (
    get_independent_test_set,
    optimize_hyperparams,
    preprocess_pandas,
    models_quick_compare,
    get_confusion_matrix,
    get_classification_report,
    full_test
)
from subpred.compositions import calculate_aac

# %% [markdown]
# # Dataset

# %%
df = create_dataset(
    keywords_substrate_filter = ["Amino-acid transport","Sugar transport"],
    keywords_component_filter = ["Transmembrane"],
    keywords_transport_filter = ["Transport"],
    input_file = "../data/raw/swissprot/uniprot-reviewed_yes.tab.gz",
    multi_substrate = "integrate",
    verbose = True,
    tax_ids_filter = [559292],
    output_log = "../logs/yeast_amino_sugar_dataset.log",
    sequence_clustering=70
)
# Out:
# cd-hit: clustered 64 sequences into 51 clusters at threshold 70

# %% [markdown]
# # Feature generation
#
# ## Labels

# %%
labels = df.keywords_transport
labels.value_counts()
# Out:
# Amino-acid transport    34
# Sugar transport         17
# Name: keywords_transport, dtype: int64

# %% [markdown]
# There will be a very low number of samples available for training and testing, only 0.8\*0.8\*17 for sugar. This is likely not enough. We will try nested LOOCV later.

# %% [markdown]
# ## AAC

# %%
df_aac = calculate_aac(df.sequence)
df_aac
# Out:
#                 A         C         D         E         F         G         H  \
# Uniprot
# Q08986   0.085179  0.025554  0.027257  0.047700  0.069847  0.078365  0.010221
# P38967   0.069257  0.023649  0.035473  0.035473  0.069257  0.089527  0.023649
# P38085   0.074313  0.022617  0.035541  0.046850  0.064620  0.069467  0.021002
# P15380   0.078150  0.025518  0.041467  0.035088  0.057416  0.092504  0.019139
# P38206   0.048780  0.012195  0.029617  0.041812  0.095819  0.045296  0.012195
# Q12300   0.074705  0.011796  0.040629  0.039318  0.045872  0.072084  0.017038
# Q12010   0.045455  0.016234  0.045455  0.038961  0.071429  0.055195  0.009740
# Q03697   0.047511  0.011312  0.033937  0.040724  0.072398  0.061086  0.015837
# Q04602   0.049479  0.022135  0.039062  0.040365  0.062500  0.052083  0.019531
# P10870   0.064480  0.007919  0.053167  0.047511  0.054299  0.072398  0.015837
# P39932   0.075571  0.015817  0.038664  0.054482  0.079086  0.080844  0.014060
# P53388   0.074013  0.014803  0.041118  0.037829  0.075658  0.075658  0.008224
# P40886   0.065026  0.031634  0.035149  0.056239  0.075571  0.080844  0.007030
# P42833   0.040741  0.018519  0.031481  0.042593  0.068519  0.079630  0.012963
# P38156   0.091205  0.029316  0.042345  0.058632  0.055375  0.079805  0.004886
# P43548   0.100358  0.008961  0.035842  0.037634  0.062724  0.087814  0.016129
# P50944   0.049088  0.005610  0.046283  0.030856  0.075736  0.058906  0.021038
# P38084   0.082102  0.016420  0.037767  0.039409  0.073892  0.078818  0.018062
# P38971   0.075044  0.012216  0.031414  0.048866  0.078534  0.076789  0.005236
# P04817   0.037288  0.069492  0.064407  0.069492  0.027119  0.035593
# P47082   0.046512  0.089701  0.071429  0.069767  0.008306  0.019934
# P38090   0.040268  0.075503  0.048658  0.070470  0.018456  0.052013
# P32467   0.031250  0.069444  0.062500  0.088542  0.022569  0.045139
# P06775   0.039801  0.096186  0.066335  0.072968  0.021559  0.024876
# P40107   0.020772  0.109792  0.059347  0.077151  0.017804  0.032641
# P19807   0.021314  0.101243  0.049734  0.067496  0.026643  0.033748
# P54854   0.029982  0.081129  0.045855  0.081129  0.022928  0.045855
# P38695   0.043919  0.082770  0.069257  0.079392  0.020270  0.050676
# P43581   0.045788  0.082418  0.064103  0.087912  0.023810  0.042125
# P53048   0.032468  0.086039  0.061688  0.051948  0.024351  0.037338
# P32487   0.034370  0.073650  0.050736  0.083470  0.026187  0.044190
# Q12520   0.017699  0.073746  0.064897  0.070796  0.026549  0.032448
# P38734   0.023810  0.095238  0.049451  0.097070  0.018315  0.036630
# P50276   0.022648  0.069686  0.047038  0.083624  0.022648  0.047038
# Q12029   0.048930  0.079511  0.064220  0.085627  0.012232  0.015291
# Q04301   0.033808  0.101423  0.058719  0.069395  0.014235  0.046263
# P25594   0.026201  0.074236  0.061135  0.069869  0.010917  0.026201
# P38358   0.033755  0.122363  0.065401  0.046414  0.012658  0.029536
# P38279   0.023649  0.077703  0.023649  0.060811  0.016892  0.040541
# P40004   0.035088  0.084795  0.070175  0.064327  0.011696  0.046784
# Q06328   0.041009  0.104101  0.069401  0.037855  0.009464  0.053628
# Q12235   0.028249  0.075330  0.060264  0.060264  0.020716  0.024482
# Q04162   0.048649  0.106306  0.070270  0.063063  0.010811  0.041441
# P48813   0.040724  0.082956  0.040724  0.075415  0.019608  0.039216

# %% [markdown]
# ### Independent test set

# %%
X, y, feature_names, sample_names = preprocess_pandas(
    df_aac, labels, return_names=True
)
(
    X_train,
    X_test,
    y_train,
    y_test,
    sample_names_train,
    sample_names_test,
) = get_independent_test_set(X, y, sample_names=sample_names, test_size=0.2)

# %% [markdown]
# ### Model selection

# %%
models_quick_compare(X_train, y_train)
# Out:
#                                                         0      1      2  \
# est
# GaussianNB()                                        0.667  0.564  1.000
# KNeighborsClassifier()                              1.000  0.795  0.667
# LinearSVC(class_weight='balanced', max_iter=100...  0.855  0.667  0.873
# LinearSVC(max_iter=1000000.0, random_state=0)       0.855  0.667  0.873
# RandomForestClassifier(class_weight='balanced',...  0.795  0.795  0.855
# RandomForestClassifier(random_state=0)              0.795  0.667  0.855
# SGDClassifier(random_state=0)                       0.855  0.667  0.873
# SVC(class_weight='balanced', random_state=0)        1.000  0.795  1.000
# SVC(random_state=0)                                 0.795  0.795  0.855
#
#                                                         3      4   mean    std
# est
# GaussianNB()                                        0.385  0.564  0.636  0.228
# KNeighborsClassifier()                              0.385  0.667  0.703  0.224
# LinearSVC(class_weight='balanced', max_iter=100...  0.333  0.385  0.622  0.254
# LinearSVC(max_iter=1000000.0, random_state=0)       0.333  0.385  0.622  0.254
# RandomForestClassifier(class_weight='balanced',...  0.385  0.385  0.643  0.237
# RandomForestClassifier(random_state=0)              0.385  0.385  0.617  0.223
# SGDClassifier(random_state=0)                       0.333  0.385  0.622  0.254
# SVC(class_weight='balanced', random_state=0)        0.385  0.667  0.769  0.258
# SVC(random_state=0)                                 0.385  0.667  0.699  0.189

# %% [markdown]
# ### Parameter tuning
#
# RBF kernel delivers slightly better results

# %%
gsearch = optimize_hyperparams(X_train, y_train, kernel="linear", dim_reduction=None)
# Out:
# {'linearsvc__C': 0.1, 'linearsvc__class_weight': None, 'linearsvc__dual': True, 'linearsvc__max_iter': 100000000.0}
# 0.689

# %%
gsearch = optimize_hyperparams(X_train, y_train, kernel="rbf", dim_reduction=None, C=[1,0.1,10])
best_estimator_svc = gsearch
# Out:
# {'svc__C': 1, 'svc__class_weight': 'balanced', 'svc__gamma': 'scale'}
# 0.769

# %% [markdown]
# ### Dimensionality reduction

# %% [markdown]
# Kbest performs slightly better:

# %%
gsearch = optimize_hyperparams(
    X_train, y_train, kernel="rbf", dim_reduction="kbest"#, C=[1,10,100], gamma=["scale"]
)
best_estimator_svc_kbest = gsearch
# Out:
# {'selectkbest__k': 5, 'svc__C': 1, 'svc__class_weight': None, 'svc__gamma': 'scale'}
# 0.785

# %% [markdown]
# PCA improves the results a bit more_

# %%
gsearch = optimize_hyperparams(
    X_train,
    y_train,
    kernel="rbf",
    dim_reduction="pca",
    # C=[1, 10, 100],
    # gamma=["scale", 0.1, 0.01, 0.001],
)
best_estimator_svc_pca = gsearch
# Out:
# {'pca__n_components': 0.94, 'svc__C': 1, 'svc__class_weight': 'balanced', 'svc__gamma': 0.1}
# 0.769

# %% [markdown]
# ### Validation
#
# The test set is only made up of 10 amino and 7 sugar transporters, so one miss-classification can already change the score by quite a large amount. The sample count does not seem to be enough for a good model.
#
# The PCA model seems to lead to less overfitting, having better scores on the test set.

# %%
get_confusion_matrix(X_test, y_test, best_estimator_svc_kbest, labels=labels)
# Out:
# predicted             Amino-acid transport  Sugar transport
# observed
# Amino-acid transport                     6                1
# Sugar transport                          3                1

# %%
get_classification_report(X_test, y_test, best_estimator_svc_kbest, labels=labels)
# Out:
#                       precision  recall  f1-score  support
# Amino-acid transport      0.667   0.857     0.750        7
# Sugar transport           0.500   0.250     0.333        4
# macro avg                 0.583   0.554     0.542       11
# weighted avg              0.606   0.636     0.598       11

# %%
get_confusion_matrix(X_test, y_test, best_estimator_svc_pca, labels=labels)
# Out:
# predicted             Amino-acid transport  Sugar transport
# observed
# Amino-acid transport                     7                0
# Sugar transport                          3                1

# %%
get_classification_report(X_test, y_test, best_estimator_svc_pca, labels=labels)
# Out:
#                       precision  recall  f1-score  support
# Amino-acid transport      0.700   1.000     0.824        7
# Sugar transport           1.000   0.250     0.400        4
# macro avg                 0.850   0.625     0.612       11
# weighted avg              0.809   0.727     0.670       11

# %% [markdown]
# ## Checking dependence on train test split
#
# Especially the performance of the sugar transporter test set is not good, it's the class with the fewest number of samples

# %% [markdown]
# #### PCA model:
#
# The average model performance does not improve with other train test splits:

# %%
df_scores, df_params = full_test(
    df_aac, labels, dim_reduction="pca", kernel="rbf", repetitions=10
)
display(
    df_scores.groupby(["label", "dataset"], as_index=False)
    .mean()
    .pivot(index="label", columns="dataset", values="F1 score")
)
display(
    df_scores.groupby(["label", "dataset"], as_index=False)
    .std()
    .pivot(index="label", columns="dataset", values="F1 score")
)
# Out:
# dataset                 test   train
# label
# Amino-acid transport  0.8143  0.8959
# Sugar transport       0.5693  0.7593
# dataset                   test     train
# label
# Amino-acid transport  0.044756  0.032895
# Sugar transport       0.142985  0.083758

# %% [markdown]
# #### Kbest
#
# The same is true for kbest:

# %%
df_scores, df_params = full_test(
    df_aac, labels, dim_reduction="kbest", kernel="rbf", repetitions=10
)
display(
    df_scores.groupby(["label", "dataset"], as_index=False)
    .mean()
    .pivot(index="label", columns="dataset", values="F1 score")
)
display(
    df_scores.groupby(["label", "dataset"], as_index=False)
    .std()
    .pivot(index="label", columns="dataset", values="F1 score")
)
# Out:
# dataset                 test   train
# label
# Amino-acid transport  0.7996  0.9260
# Sugar transport       0.5391  0.8173
# dataset                   test     train
# label
# Amino-acid transport  0.070122  0.022371
# Sugar transport       0.167901  0.063901

# %% [markdown]
# ## LOOCV
#
# To increase the number of samples availale for training, we carry out a nested leave one out cross validation:

# %%
df_scores, df_params = full_test(
    df_aac, labels, dim_reduction="pca", kernel="rbf", repetitions=10, cross_val_method="loocv"
)
display(
    df_scores.groupby(["label", "dataset"], as_index=False)
    .mean()
    .pivot(index="label", columns="dataset", values="F1 score")
)
display(
    df_scores.groupby(["label", "dataset"], as_index=False)
    .std()
    .pivot(index="label", columns="dataset", values="F1 score")
)
# Out:
# dataset                 test   train
# label
# Amino-acid transport  0.8008  0.9122
# Sugar transport       0.5370  0.7492
# dataset                   test     train
# label
# Amino-acid transport  0.080168  0.033947
# Sugar transport       0.128152  0.113284

# %%
df_params
# Out:
#                           0     1     2         3         4         5  \
# pca__n_components      0.93  0.98  0.97      0.94       0.8       0.9
# svc__C                   10    10    10         1        10         1
# svc__class_weight  balanced  None  None  balanced  balanced  balanced
# svc__gamma            scale  0.01  0.01     scale     scale     scale
#
#                           6     7         8         9
# pca__n_components      0.83  0.98      0.93      0.85
# svc__C                    1    10         1         1
# svc__class_weight  balanced  None  balanced  balanced
# svc__gamma            scale  0.01       0.1     scale

# %% [markdown]
# With LOOCV, there is a slight improvement in average F1 scores and their standard deviations. It becomes clear that AAC alone is not suitable for this classification task.

# %%
df_scores, df_params = full_test(
    df_aac, labels, dim_reduction="kbest", kernel="rbf", repetitions=10, cross_val_method="loocv"
)
display(
    df_scores.groupby(["label", "dataset"], as_index=False)
    .mean()
    .pivot(index="label", columns="dataset", values="F1 score")
)
display(
    df_scores.groupby(["label", "dataset"], as_index=False)
    .std()
    .pivot(index="label", columns="dataset", values="F1 score")
)
